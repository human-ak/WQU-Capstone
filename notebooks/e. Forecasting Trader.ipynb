# %% [markdown]
# ### Import Libraries

# %%
import tensorflow as tf
import numpy as np
import random
import os

# Reproducibility
seed = 2
os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# Optional: disable eager execution (if using graph mode code)
tf.compat.v1.disable_eager_execution()

# Session config
session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1,
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(config=session_conf)

# Set this session as default for everything that follows
# No set_session needed — use a context manager instead
with sess.as_default():
    # your model/code here
    pass
# Out:
# 2025-04-29 19:40:09.673956: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-29 19:40:09.683743: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745955609.696617   35676 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745955609.700347   35676 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745955609.710255   35676 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745955609.710275   35676 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745955609.710276   35676 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745955609.710277   35676 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-29 19:40:09.713287: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1745955611.780497   35676 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9316 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
import warnings
warnings.filterwarnings('ignore')

from pylab import *

import pandas as pd
import pickle
import time
import sys
import json
import os

# import statsmodels
# import statsmodels.api as sm
# from statsmodels.tsa.stattools import coint, adfuller

import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Import Datetime and the Pandas DataReader
from datetime import datetime
from pandas_datareader import data, wb

# Import scikit instruments
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn import preprocessing
from sklearn.metrics import silhouette_score
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import MinMaxScaler, StandardScaler


# Import keras
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, LSTM, GRU, Dropout, TimeDistributed
from keras.optimizers import SGD, Adam
from tensorflow.keras.layers import Conv1D, MaxPooling1D 
#from keras.layers.convolutional import Conv1D
#from keras.layers.convolutional import MaxPooling1D
from keras.callbacks import EarlyStopping, ProgbarLogger

# %% [markdown]
# ### Import Classes

# %%
os.getcwd()
# Out:
# '/mnt/c/Users/ansel/AppData/Local/Programs/Microsoft VS Code'

# %%
os.chdir('/mnt/d/GitHub/WQU-Capstone/notebooks/classes')

os.getcwd()
# Out:
# '/mnt/d/GitHub/WQU-Capstone/notebooks/classes'

# %%
# %load_ext autoreload
# %aimport class_SeriesAnalyser, class_Trader, class_DataProcessor, class_ForecastingTrader
# %autoreload 1
# Out:
# I0000 00:00:1745955614.234797   35676 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9316 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
series_analyser = class_SeriesAnalyser.SeriesAnalyser()
trader = class_Trader.Trader()
data_processor = class_DataProcessor.DataProcessor()
forecasting_trader = class_ForecastingTrader.ForecastingTrader()

# %% [markdown]
# Function to evaluate forecasting results:

# %%
def evaluate_forecasting(n_pairs, true_values, prediction_values):
    mse, mae, rmse, accuracy, bias = list(), list(), list(), list(), list()
    std_dev = list()
    for i in range(n_pairs):
        mse.append(mean_squared_error(true_values[i], prediction_values[i]))
        rmse.append(np.sqrt(mean_squared_error(true_values[i], prediction_values[i])))
        mae.append(mean_absolute_error(true_values[i], prediction_values[i]))
        accuracy.append(forecasting_trader.calculate_direction_accuracy(true_values[i], prediction_values[i]))
        bias.append((true_values[i] - prediction_values[i]).mean())
        std_dev.append(prediction_values[i].std())
    print('{:.2f}E-4'.format(np.mean(mse)*10000))#Average MSE: 
    print('{:.2f}E-3'.format(np.mean(rmse)*1000))#Average RMSE: 
    print('{:.2f}E-3'.format(np.mean(mae)*1000))#Average RMSE: 
    print('{:.2f}%'.format(np.mean(accuracy)))#Average Directional Accuracy: 
    #print('Bias: {:.2f}E-4'.format(np.mean(bias)*10000))
    #print('Average Standard Deviation from prediction signal ', np.mean(std_dev))
    
    return mse, mae, rmse, accuracy

# %% [markdown]
# ### LSTM

# %%
def plot_loss(history, title, epoch_stop, metric='mse'):
    """
    Function to plot loss function.
    Arguments:
    history: History object with data from training.
    title: Plot title.
    """
    plt.figure(figsize=(7,5))
    #plt.grid()
    if metric == 'mse':
        plt.plot(history['loss'], label = "Training MSE")
        plt.plot(history['val_loss'], label = "Validation MSE")
        plt.plot([epoch_stop], [history['val_loss'][epoch_stop]],'o', color='Red', markersize=7)
        plt.annotate(
            'Best Epoch: 41\nValidation MSE:{:.3f}'.format(history['val_loss'][epoch_stop]),
            xy=(epoch_stop, history['val_loss'][epoch_stop]),
            xytext=(-20, 20),
            textcoords='offset points', ha='left', va='bottom',
            bbox=dict(boxstyle='round,pad=0.5', fc='grey', alpha=0.5),
            arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))
        plt.ylim((0,1.2))
        plt.ylabel('Mean Squared Error', size=12)
    elif metric == 'mae':
        plt.plot(history['mean_absolute_error'], label = "Training MAE")
        plt.plot(history['val_mean_absolute_error'], label = "Validation MAE")
        plt.plot([epoch_stop], [history['val_mean_absolute_error'][epoch_stop]],'o', color='Red', markersize=7)
        plt.annotate(
            'Best Epoch: 41\nValidation MAE:{:.3f}'.format(history['val_mean_absolute_error'][epoch_stop]),
            xy=(epoch_stop, history['val_mean_absolute_error'][epoch_stop]),
            xytext=(-20, 20),
            textcoords='offset points', ha='left', va='bottom',
            bbox=dict(boxstyle='round,pad=0.5', fc='grey', alpha=0.5),
            arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))
        plt.ylim((0,1.2))
        plt.ylabel('Mean Absolute Error', size=12)
    plt.xlabel('Epochs', size=12)
    plt.legend()
    plt.savefig('{}_history.png'.format(metric), bbox='tight')
    
def plot_predictions(summaries):
    
    n_pairs = len(summaries)
    fig, ax = plt.subplots(n_pairs, 1, figsize=(20,25))
    
    for i in range(n_pairs):
        #title('Pair: {}'.format(i))
        predictions = summaries[i]['prediction(t)']
        spread = summaries[i]['spread(t)']
        ax[i].plot(predictions, 'b')
        ax[i].plot(spread, 'r')
    return None

# %%
def read_models(path='models/'):
    all_models = [] # Creates an empty list
    for root, dirs, files in os.walk(path):
        for file in files:
            if file.endswith(".pkl"):
                with open(path+file, 'rb') as f:
                    models = pickle.load(f)
                all_models.append(models)
                
    return all_models

# %%
current_path=('/mnt/d/GitHub/WQU-Capstone/data/')
with open(current_path+'yf_5_clusters_pairs_category.pickle', 'rb') as handle: 
    pairs = pickle.load(handle)
len(pairs)
# Out:
# 20

# %%
#markers= ["o","s","+","x","<"]
plt.rcParams.update({'font.size': 17})
colors = [
    'purple', 'red', 'green', 'blue', 'orange',
    'black', 'cyan', 'magenta', 'brown', 'pink',
    'gray', 'olive', 'teal', 'navy', 'gold'
]
for i in range(len(pairs)):
    pairs[i][2]['spread'][::100].plot(figsize=(20,10), grid=True, label='{}-{}'.format(pairs[i][0],pairs[i][1]), c=colors[i % len(colors)], linewidth=2)
plt.ylabel('Spread(t)',size=12)
plt.xlabel('Year',size=12)
plt.xlim(('2018', '2024'))
plt.legend()
#plt.savefig('spreads.png', bbox_inches='tight', pad_inches=0.05)

# %% [markdown]
# ## Grid Search

# %%
rnn_models = read_models(path=current_path)

# %%
etf_list = pd.read_excel('/mnt/d/GitHub/WQU-Capstone/data/etf_list.xlsx')
ticker_segment_dict = dict(zip(etf_list['Symbol'], etf_list['Name']))
ticker_segment_dict
# Out:
# {'VXUS': 'Vanguard Total International Stock Index Fund ETF Shares',
#  'BND': 'Vanguard Total Bond Market Index Fund',
#  'QQQ': 'Invesco QQQ Trust',
#  'BNDX': 'Vanguard Total International Bond Index Fund',
#  'VTIP': 'Vanguard Short-Term Inflation-Protected Securities Index Fund ETF Shares',
#  'VCIT': 'Vanguard Intermediate-Term Corporate Bond Index Fund ETF Shares',
#  'TLT': 'iShares 20+ Year Treasury Bond ETF',
#  'VCSH': 'Vanguard Short-Term Corporate Bond Index Fund ETF Shares',
#  'VGIT': 'Vanguard Intermediate-Term Treasury Index Fund ETF Shares',
#  'MBB': 'iShares MBS ETF',
#  'IEF': 'iShares 7-10 Year Treasury Bond ETF',
#  'IUSB': 'iShares Core Total USD Bond Market ETF',
#  'VONG': 'Vanguard Russell 1000 Growth Index Fund ETF Shares',
#  'VGSH': 'Vanguard Short-Term Treasury Index Fund ETF Shares',
#  'SHY': 'iShares 1-3 Year Treasury Bond ETF',
#  'IGSB': 'iShares 1-5 Year Investment Grade Corporate Bond ETF',
#  'SHV': 'iShares Short Treasury Bond ETF',
#  'TQQQ': 'ProShares UltraPro QQQ',
#  'SMH': 'VanEck Semiconductor ETF',
#  'ACWI': 'iShares MSCI ACWI ETF',
#  'IEI': 'iShares 3-7 Year Treasury Bond ETF',
#  'IGIB': 'iShares 5-10 Year Investment Grade Corporate Bond ETF',
#  'VCLT': 'Vanguard Long-Term Corporate Bond Index Fund ETF Shares',
#  'VGLT': 'Vanguard Long-Term Treasury Index Fund ETF Shares',
#  'PFF': 'iShares Preferred and Income Securities ETF',
#  'EMB': 'iShares J.P. Morgan USD Emerging Markets Bond ETF',
#  'RDVY': 'First Trust Rising Dividend Achievers ETF',
#  'USIG': 'iShares Broad USD Investment Grade Corporate Bond ETF',
#  'SOXX': 'iShares Semiconductor ETF',
#  'SCZ': 'iShares MSCI EAFE Small-Cap ETF',
#  'QYLD': 'Global X NASDAQ 100 Covered Call ETF',
#  'CIBR': 'First Trust NASDAQ Cybersecurity ETF',
#  'SDVY': 'First Trust SMID Cap Rising Dividend Achievers ETF',
#  'FTSM': 'First Trust Enhanced Short Maturity ETF',
#  'MCHI': 'iShares MSCI China ETF',
#  'IBB': 'iShares Biotechnology ETF',
#  'ACWX': 'iShares MSCI ACWI ex U.S. ETF',
#  'PDBC': 'Invesco Optimum Yield Diversified Commodity Strategy No K-1 ETF',
#  'KBWB': 'Invesco KBW Bank ETF',
#  'ANGL': 'VanEck Fallen Angel High Yield Bond ETF',
#  'BSCR': 'Invesco BulletShares 2027 Corporate Bond ETF',
#  'SQQQ': 'ProShares UltraPro Short QQQ',
#  'FALN': 'iShares Fallen Angels USD Bond ETF',
#  'ICLN': 'iShares Global Clean Energy ETF'}

# %%
# model to test
n_in = 24
hidden_nodes = [30]
low_quantile = 0.10
high_quantile = 0.90
train_val_split = '01-01-2023'

# %%
model_rnn, cumret_val, sharperatio_val,summaries_rnn, balance_summaries_rnn = \
            forecasting_trader.run_specific_model(
                                                n_in, 
                                                hidden_nodes, 
                                                pairs,
                                                path='/mnt/d/GitHub/WQU-Capstone/models/lstm/',
                                                train_val_split=train_val_split,
                                                low_quantile=low_quantile, 
                                                high_quantile=high_quantile, 
                                                lag=1,
                                                )
# Out:
# Not considering risk-free rate
# Not considering risk-free rate
# Not considering risk-free rate
# Not considering risk-free rate
# Not considering risk-free rate
# Not considering risk-free rate
# Not considering risk-free rate
# Not considering risk-free rate
# Not considering risk-free rate
# Not considering risk-free rate
# Not considering risk-free rate
# Not considering risk-free rate
# Not considering risk-free rate
# Not considering risk-free rate

# %%
performance_rnn = [(summaries_rnn[i], balance_summaries_rnn[i]) for i in range(len(pairs))]

# %%
performance_rnn
# Out:
# [(            prediction(t)  prediction(t+1)  spread(t)  predicted_change(%)  \
#   Date
#   2023-01-03     -13.748846                0 -13.633182             0.000000
#   2023-01-04     -13.645265                0 -13.567966            -0.088625
#   2023-01-05     -13.581827                0 -13.509320            -0.102160
#   2023-01-06     -13.532570                0 -13.467257            -0.172100
#   2023-01-09     -13.496862                0 -13.428806            -0.219833
#   ...                   ...              ...        ...                  ...
#   2023-12-22     -13.510140                0 -13.547376            -0.017856
#   2023-12-26     -13.548466                0 -13.459069            -0.008046
#   2023-12-27     -13.458666                0 -13.374942             0.002994
#   2023-12-28     -13.378857                0 -13.396667            -0.029272
#   2023-12-29     -13.406292                0 -13.537608            -0.071848
#
#               position_during_day  position_return  position_ret_with_costs  \
#   Date
#   2023-01-03                  0.0              0.0                      0.0
#   2023-01-04                  0.0              0.0                      0.0
#   2023-01-05                  0.0              0.0                      0.0
#   2023-01-06                  0.0              0.0                      0.0
#   2023-01-09                  0.0              0.0                      0.0
#   ...                         ...              ...                      ...
#   2023-12-22                  0.0              0.0                      0.0
#   2023-12-26                  0.0              0.0                      0.0
#   2023-12-27                  0.0              0.0                      0.0
#   2023-12-28                  0.0              0.0                      0.0
#   2023-12-29                  0.0              0.0                      0.0
#
#               trading_days  ret_with_costs predicted_direction true_direction
#   Date
#   2023-01-03             0             0.0                   0            NaN
#   2023-01-04             0             0.0                  -1              1
#   2023-01-05             0             0.0                  -1              1
#   2023-01-06             0             0.0                  -1              1
#   2023-01-09             0             0.0                  -1              1
#   ...                  ...             ...                 ...            ...
#   2023-12-22             0             0.0                  -1             -1
#   2023-12-26             0             0.0                  -1              1
#   2023-12-27             0             0.0                   1              1
#   2023-12-28             0             0.0                  -1             -1
#   2023-12-29             0             0.0                  -1             -1
#
#   [250 rows x 11 columns],
#               account_balance  pnl  pnl_y  pnl_x  leg_y     leg_x  returns  \
#   Date
#   2023-01-03                1    0      0      0      1  0.744524      0.0
#   2023-01-04                1    0      0      0      1  0.744524      0.0
#   2023-01-05                1    0      0      0      1  0.744524      0.0
#   2023-01-06                1    0      0      0      1  0.744524      0.0
#   2023-01-09                1    0      0      0      1  0.744524      0.0
#   ...                     ...  ...    ...    ...    ...       ...      ...
#   2023-12-22                1    0      0      0      1  0.744524      0.0
#   2023-12-26                1    0      0      0      1  0.744524      0.0
#   2023-12-27                1    0      0      0      1  0.744524      0.0
#   2023-12-28                1    0      0      0      1  0.744524      0.0
#   2023-12-29                1    0      0      0      1  0.744524      0.0
#
#               position_trigger  numUnits        BND         IEI  \
#   Date
#   2023-01-03               0.0       0.0  66.850052  108.100258
#   2023-01-04               0.0       0.0  67.229568  108.522408
#   2023-01-05               0.0       0.0  67.155518  108.344177
#   2023-01-06               0.0       0.0  67.896027  109.282288
#   2023-01-09               0.0       0.0  68.081154  109.479294
#   ...                      ...       ...        ...         ...
#   2023-12-22               0.0       0.0  70.076881  112.319092
#   2023-12-26               0.0       0.0  70.143723  112.290260
#   2023-12-27               0.0       0.0  70.592705  112.780312
#   2023-12-28               0.0       0.0  70.420753  112.578537
#   2023-12-29               0.0       0.0  70.258347  112.549706
#
#               trading_duration  position_ret_with_costs
#   Date
#   2023-01-03                 0                      0.0
#   2023-01-04                 0                      0.0
#   2023-01-05                 0                      0.0
#   2023-01-06                 0                      0.0
#   2023-01-09                 0                      0.0
#   ...                      ...                      ...
#   2023-12-22                 0                      0.0
#   2023-12-26                 0                      0.0
#   2023-12-27                 0                      0.0
#   2023-12-28                 0                      0.0
#   2023-12-29                 0                      0.0
#
#   [250 rows x 13 columns]),
#  (            prediction(t)  prediction(t+1)  spread(t)  predicted_change(%)  \
#   Date
#   2023-01-
1.000000  0.0    0.0    0.0  1.000000  0.924027      0.0
#   2023-01-04         1.000000  0.0    0.0    0.0  1.000000  0.924027      0.0
#   2023-01-05         1.000000  0.0    0.0    0.0  1.000000  0.924027      0.0
#   2023-01-06         1.000000  0.0    0.0    0.0  1.000000  0.924027      0.0
#   2023-01-09         1.000000  0.0    0.0    0.0  1.000000  0.924027      0.0
#   ...                     ...  ...    ...    ...       ...       ...      ...
#   2023-12-22         0.987703  0.0    0.0    0.0  0.997155  0.920684      0.0
#   2023-12-26         0.987703  0.0    0.0    0.0  0.997155  0.920684      0.0
#   2023-12-27         0.987703  0.0    0.0    0.0  0.997155  0.920684      0.0
#   2023-12-28         0.987703  0.0    0.0    0.0  0.997155  0.920684      0.0
#   2023-12-29         0.987703  0.0    0.0    0.0  0.997155  0.920684      0.0
#
#               position_trigger  numUnits       FALN       ANGL  \
#   Date
#   2023-01-03               0.0       0.0  21.538139  23.689486
#   2023-01-04               0.0       0.0  21.756760  23.934616
#   2023-01-05               0.0       0.0  21.721786  23.855824
#   2023-01-06               0.0       0.0  21.975374  24.170979
#   2023-01-09               0.0       0.0  22.080313  24.293547
#   ...                      ...       ...        ...        ...
#   2023-12-22               0.0       0.0  24.466444  26.698093
#   2023-12-26               0.0       0.0  24.466444  26.698093
#   2023-12-27               0.0       0.0  24.531193  26.791502
#   2023-12-28               0.0       0.0  24.466444  26.671276
#   2023-12-29               0.0       0.0  24.420191  26.615784
#
#               trading_duration  position_ret_with_costs
#   Date
#   2023-01-03                 0                      0.0
#   2023-01-04                 0                      0.0
#   2023-01-05                 0                      0.0
#   2023-01-06                 0                      0.0
#   2023-01-09                 0                      0.0
#   ...                      ...                      ...
#   2023-12-22                 0                      0.0
#   2023-12-26                 0                      0.0
#   2023-12-27                 0                      0.0
#   2023-12-28                 0                      0.0
#   2023-12-29                 0                      0.0
#
#   [250 rows x 13 columns])]

# %%
#print('\n')
results, pairs_summary = trader.summarize_results(sharperatio_val,
                                                  cumret_val,
                                                  performance_rnn,
                                                  pairs, ticker_segment_dict,
                                                  n_years=1)
# Out:
# Annual ROI:  -1.3042181234848016
# 0.0 % of the pairs had positive returns
# Not considering risk-free rate
# Total number of trades:  31
# Positive trades:  2
# Negative trades:  29
# Total Drawdown Days: 112 days
# Max DD period: 1 days
# Maximum drawdown of portfolio: -1.36%

# %%
pairs_summary
# Out:
#     Leg1                                         Leg1_Segmt  Leg2  \
# 0    BND              Vanguard Total Bond Market Index Fund   IEI
# 1    BND              Vanguard Total Bond Market Index Fund   IEI
# 2    BND              Vanguard Total Bond Market Index Fund   IEI
# 3   VCSH  Vanguard Short-Term Corporate Bond Index Fund ...  IGSB
# 4    BND              Vanguard Total Bond Market Index Fund   IEI
# 5    BND              Vanguard Total Bond Market Index Fund   IEI
# 6   ANGL            VanEck Fallen Angel High Yield Bond ETF  FALN
# 7   VCSH  Vanguard Short-Term Corporate Bond Index Fund ...  IGSB
# 8   VCSH  Vanguard Short-Term Corporate Bond Index Fund ...  IGSB
# 9   VCSH  Vanguard Short-Term Corporate Bond Index Fund ...  IGSB
# 1        0.000000                           NaN
# 2        0.000000                           NaN
# 3        0.000000                           NaN
# 4        0.000000                           NaN
# 5        0.000000                           NaN
# 6       -0.525774                     50.000000
# 7       -0.805232                      0.000000
# 8       -0.805232                      0.000000
# 9       -0.805232                      0.000000
# 10      -1.150283                      0.000000
# 11      -1.159417                     33.333333
# 12      -1.161559                      0.000000
# 13      -1.163351                      0.000000
# 14      -1.386891                      0.000000
# 15      -1.514952                      0.000000
# 16      -1.532024                      0.000000
# 17      -1.532024                      0.000000
# 18      -1.551368                      0.000000
# 19      -1.756185                      0.000000

# %%
results
# Out:
# {'n_pairs': 20,
#  'portfolio_sharpe_ratio': np.float64(-1.9688985714566716),
#  'avg_total_roi': np.float64(-1.304218123484798),
#  'avg_annual_roi': np.float64(-1.3042181234848016),
#  'pct_positive_trades_per_pair': np.float64(5.952380952380952),
#  'pct_pairs_with_positive_results': 0.0,
#  'avg_half_life': np.float64(10.0),
#  'avg_hurst_exponent': np.float64(0.2360200034798948)}

# %% [markdown]
# Training:

# %%
init = model_rnn[0]['predictions_train'].index[0]
true_train = [pairs[i][2]['spread'][init:train_val_split] for i in range(len(pairs))]
predictions_train = [model_rnn[i]['predictions_train'] for i in range(len(pairs))]
_ = evaluate_forecasting(len(pairs), true_train, predictions_train)
# Out:
# 36.07E-4
# 53.15E-3
# 34.70E-3
# 40.18%

# %% [markdown]
# Validation:

# %%
true_val = [summaries_rnn[i]['spread(t)'] for i in range(len(pairs))]
predictions = [summaries_rnn[i]['prediction(t)'] for i in range(len(pairs))]
_ = evaluate_forecasting(len(pairs), true_val, predictions)
# Out:
# 34.88E-4
# 46.86E-3
# 36.92E-3
# 37.68%

# %% [markdown]
# **Test unrestricted**

# %%
current_path = '/mnt/d/GitHub/WQU-Capstone/models/lstm/'

# %%
model_rnn, cumret_test, sharperatio_test, summaries_rnn, balance_summaries_rnn = \
        forecasting_trader.test_specific_model(n_in, hidden_nodes, pairs, path=current_path,
                                               low_quantile=low_quantile, high_quantile=high_quantile, lag=1, 
                                               profitable_pairs_indices=range(len(pairs)))
performance_rnn = [(summaries_rnn[i], balance_summaries_rnn[i]) for i in range(len(pairs))]
print('\n')
results, pairs_summary = trader.summarize_results(sharperatio_test,
                                                  cumret_test,
                                                  performance_rnn,
                                                  pairs, ticker_segment_dict,
                                                  n_years=1)
# Out:
# Annual ROI:  0.0
# 0.0 % of the pairs had positive returns
# Not considering risk-free rate
# Total number of trades:  0
# Positive trades:  0
# Negative trades:  0
# Total Drawdown Days: 0 days
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 7
#       5 performance_rnn = [(summaries_rnn[i], balance_summaries_rnn[i]) for i in range(len(pairs))]
#       6 print('\n')
# ----> 7 results, pairs_summary = trader.summarize_results(sharperatio_test,
#       8                                                   cumret_test,
#       9                                                   performance_rnn,
#      10                                                   pairs, ticker_segment_dict,
#      11                                                   n_years=1)
#
# File /mnt/d/GitHub/WQU-Capstone/notebooks/classes/class_Trader.py:710, in Trader.summarize_results(self, sharpe_results, cum_returns, performance, total_pairs, ticker_segment_dict, n_years)
#     708     total_account_balance = total_account_balance + performance[index][1]['account_balance']
#     709 total_account_balance = total_account_balance.fillna(method='ffill')
# --> 710 max_dd, max_dd_duration, total_dd_duration = self.calculate_maximum_drawdown(total_account_balance)
#     711 print('Maximum drawdown of portfolio: {:.2f}%'.format(max_dd))
#     713 return results, pairs_df
#
# TypeError: cannot unpack non-iterable int object

# %% [markdown]
# Test:

# %%
true_test = [summaries_rnn[i]['spread(t)'] for i in range(len(pairs))]
predictions = [summaries_rnn[i]['prediction(t)'] for i in range(len(pairs))]
_ = evaluate_forecasting(len(pairs), true_test, predictions)
# Out:
# 149.23E-4
# 94.55E-3
# 84.45E-3
# 42.23%

# %% [markdown]
# **Test with active pairs on validation set**

# %%
cumret_val = np.asarray(cumret_val)
profitable_pairs_indices = np.argwhere(cumret_val > 0)
profitable_pairs = [pairs[i] for i in profitable_pairs_indices.flatten()]
model_rnn, cumret_test, sharperatio_test, summaries_rnn, balance_summaries_rnn = \
        forecasting_trader.test_specific_model(n_in, hidden_nodes, pairs, path=current_path,
                                               low_quantile=low_quantile, high_quantile=high_quantile, lag=1, 
                                               profitable_pairs_indices=profitable_pairs_indices)
performance_rnn = [(summaries_rnn[i], balance_summaries_rnn[i]) for i in range(len(profitable_pairs))]
print('\n')
results, pairs_summary = trader.summarize_results(sharperatio_test,
                                                  cumret_test,
                                                  performance_rnn,
                                                  profitable_pairs, ticker_segment_dict,
                                                  n_years=1)
# Out:
# Annual ROI:  nan
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[23], line 10
#       8 performance_rnn = [(summaries_rnn[i], balance_summaries_rnn[i]) for i in range(len(profitable_pairs))]
#       9 print('\n')
# ---> 10 results, pairs_summary = trader.summarize_results(sharperatio_test,
#      11                                                   cumret_test,
#      12                                                   performance_rnn,
#      13                                                   profitable_pairs, ticker_segment_dict,
#      14                                                   n_years=1)
#
# File /mnt/d/GitHub/WQU-Capstone/notebooks/classes/class_Trader.py:655, in Trader.summarize_results(self, sharpe_results, cum_returns, performance, total_pairs, ticker_segment_dict, n_years)
#     643 def summarize_results(self, sharpe_results, cum_returns, performance, total_pairs, ticker_segment_dict, n_years):
#     644     """
#     645     This function summarizes interesting metrics to include in the final output
#     646     :param sharpe_results: array containing sharpe results for each pair
#    (...)    652     :return: dictionary with metrics of interest
#     653     """
# --> 655     avg_total_roi, avg_annual_roi, positive_pct = self.calculate_metrics(cum_returns, n_years)
#     657     portfolio_sharpe_ratio = self.calculate_portfolio_sharpe_ratio(performance, total_pairs)
#     659     sorted_indices = np.flip(np.argsort(sharpe_results), axis=0)
#
# File /mnt/d/GitHub/WQU-Capstone/notebooks/classes/class_Trader.py:638, in Trader.calculate_metrics(self, cum_returns, n_years)
#     635 print('Annual ROI: ', avg_annual_roi)
#     637 cum_returns_filtered = np.asarray(cum_returns_filtered)
# --> 638 positive_pct = len(cum_returns_filtered[cum_returns_filtered > 0]) * 100 / len(cum_returns_filtered)
#     639 print('{} % of the pairs had positive returns'.format(positive_pct))
#     641 return avg_total_roi, avg_annual_roi, positive_pct
#
# ZeroDivisionError: division by zero

# %%
#print('Corrected Sharpe Ratio', 0.031555590854708014*15.81)
