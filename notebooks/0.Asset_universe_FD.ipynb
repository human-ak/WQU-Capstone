# %% [markdown]
# # Setup

# %%
import talib as ta
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import pickle
import tiingo
import financedatabase as fd
import datetime
import financetoolkit
from utils.api_keys import API_KEYS

# %% [markdown]
# # Screening ETFs from Finance Database

# %% [markdown]
# We will use the [Finance Database](https://github.com/JerBouma/FinanceDatabase) package to identify an asset universe.

# %%
#Setting the api key as Financial Modeling Prep
API_KEY = API_KEYS['fmp']

# %%
# Initializing the ETFs database
etfs = fd.ETFs()

# %%
etfs.data
# Out:
#                                                        name currency  \
# symbol
# ^ACWI                                         ISHARES TRUST      USD
# ^ADFI-IV                    NFIELD DYNAMIC FIXED INCOME ETF      USD
# ^ADRE                                    INVESCO ACTIVELY M      USD
# ^ARB-EU                      ALTSHARES MERGER ARBITRAGE ETF      USD
# ^ARB-IV                      ALTSHARES MERGER ARBITRAGE ETF      USD
# ...                                                     ...      ...
# VGFPF     Vanguard Funds Public Limited Company - Vangua...      NaN
# VFDEF     Vanguard Funds Public Limited Company - Vangua...      NaN
# WSDMF     WisdomTree Issuer ICAV - WisdomTree Europe Equ...      NaN
# WDSSF     WisdomTree Issuer ICAV - WisdomTree US Quality...      NaN
# ZKBHF                                          ZKB Gold ETF      NaN
#
#                                                     summary category_group  \
# symbol
# ^ACWI     The iShares MSCI ACWI ETF seeks to track the i...     Financials
# ^ADFI-IV  The NFIELD DYNAMIC FIXED INCOME ETF (ADFI) is ...   Fixed Income
# ^ADRE     The Invesco Active REIT ETF is an actively man...    Real Estate
# ^ARB-EU   The ALTSHARES MERGER ARBITRAGE ETF seeks capit...   Alternatives
# ^ARB-IV   The ALTSHARES MERGER ARBITRAGE ETF seeks capit...   Alternatives
# ...                                                     ...            ...
# VGFPF     The Vanguard S&P 500 UCITS ETF (USD) Accumulat...       Equities
# VFDEF     VFDEF is an exchange-traded fund (ETF) that ai...       Equities
# WSDMF     The WisdomTree Issuer ICAV - WisdomTree Europe...       Equities
# WDSSF     The WisdomTree Issuer ICAV - WisdomTree US Qua...       Equities
# ZKBHF     The ZKB Gold ETF provides investors with expos...    Commodities
#
#                    category                         family exchange
# symbol
# ^ACWI     Developed Markets     BlackRock Asset Management      NIM
# ^ADFI-IV    Corporate Bonds                            NaN      ASE
# ^ADRE                 REITs  Invesco Investment Management      NIM
# ^ARB-EU                 NaN                      AltShares      ASE
# ^ARB-IV                 NaN                      AltShares      ASE
# ...                     ...                            ...      ...
# VGFPF                   NaN                            NaN      NaN
# VFDEF                   NaN                            NaN      NaN
# WSDMF                   NaN                            NaN      NaN
# WDSSF                   NaN                            NaN      NaN
# ZKBHF                   NaN                            NaN      NaN
#
# [36552 rows x 7 columns]

# %%
etfs.data.loc['ARKK']
# Out:
# name                                             ARK Innovation ETF
# currency                                                        USD
# summary           The investment seeks long-term growth of capit...
# category_group                               Information Technology
# category                                                    Factors
# family                                                ARK ETF Trust
# exchange                                                        PCX
# Name: ARKK, dtype: object

# %%
#List columns options
etfs.show_options()
# Out:
# {'currency': array(['AUD', 'CAD', 'CHF', 'CNY', 'CZK', 'DKK', 'EUR', 'GBP', 'HUF',
#         'ILA', 'ISK', 'JPY', 'KRW', 'MXN', 'NOK', 'QAR', 'RUB', 'SAR',
#         'SEK', 'SGD', 'THB', 'TRY', 'TWD', 'USD'], dtype=object),
#  'category_group': array(['Alternatives', 'Cash', 'Commodities', 'Communication Services',
#         'Consumer Discretionary', 'Consumer Staples', 'Currencies',
#         'Derivatives', 'Energy', 'Equities', 'Financials', 'Fixed Income',
#         'Health Care', 'Industrials', 'Information Technology',
#         'Materials', 'Real Estate', 'Utilities'], dtype=object),
#  'category': array(['Alternative', 'Blend', 'Bonds', 'Cash', 'Commercial Real Estate',
#         'Commodities Broad Basket', 'Communications',
#         'Consumer Discretionary', 'Consumer Staples', 'Corporate Bonds',
#         'Currencies', 'Derivatives', 'Developed Markets',
#         'Emerging Markets', 'Energy', 'Equities', 'Factors', 'Financials',
#         'Frontier Markets', 'Government Bonds', 'Growth', 'Health Care',
#         'High Yield Bonds', 'Industrials',
#         'Inflation-Protected Securities', 'Investment Grade Bonds',
#         'Large Cap', 'Materials', 'Micro Cap', 'Mid Cap',
#         'Money Market Instruments', 'Municipal Bonds', 'REITs',
#         'Real Estate Development', 'Real Estate Services',
#         'Residential Real Estate', 'Small Cap', 'Technology', 'Trading',
#         'Treasury Bonds', 'Utilities', 'Value'], dtype=object),
#  'family': array(['1832 Asset Management', '21Shares', '2nd Vote Funds',
#         '3 Banken-Generali Investment-Gesellschaft',
#         'ACATIS Investment Management', 'ACV ETFs', 'AGF Investments',
#         'ALPS ETF Trust', 'ARK ETF Trust', 'ASYMshsare', 'ATAC Fund',
#         'AXA Investment Management', 'AXA Investment Managers',
#         'AXA World Funds', 'Aberdeen Standard Investments',
#         'Absolute Investment Advisers',
#         'Accelerate Financial Technologies', 'Acquirers Funds', 'Acruence',
#         'Actinver Casa de Bolsa', 'Adasina', 'AdvisorShares',
#         'Aegon Investment Management', 'Affinity', 'Alerian', 'Alger',
#         'AllianceBernstein', 'Allianz Global Investors Fund',
#         'Allianz Investment Management', 'Alpha Architect', 'AlphaClone',
#         'AlphaMark', 'AltShares', 'Alternative Access Funds',
#         'American Century Investments', 'Amphitryon Capital Management',
#         'Amplify ETFs', 'Amundi Asset Management', 'Anfield',
#         'Aptus Capital Advisors', 'ArrowShares', 'Asset Management One',
#         'Avantis Investors', 'Aware', 'BBVA Asset Management',
#         'BMO Capital Markets', 'BNP Paribas Asset Management',
#         'BNY Mellon', 'BOCI-Prudential Asset Management',
#         'Baillie Gifford', 'Ballast Asset Management',
#         'Bangkok Capital Asset Management', 'Barclays',
#         'Baring Asset Management', 'BetaShares Capital', 'Bitcoin Capital',
#         'BlackRock Asset Management', 'Bristol Gate Capital Partners',
#         'Brompton Funds', 'CBOE Vest', 'CI Investments',
#         'CIBC Asset Management', 'CSOP Asset Management',
#         'CTBC Securities Investment Trust', 'Cabana', 'Cabot ETF Partners',
#         'Caldwell Investment Management', 'Cambria ETF Trust',
#         'Candriam Lux', 'Capital Investment Trust', 'Carmignac Patrimoine',
#         'Cathay Securities Investment Trust', 'Change Finance',
#         'Changebridge', 'ClearShares', 'CoinShares',
#         'Columbia Threadneedle', 'Core Alternative Capital', 'CornerCap',
#         'Credit Suisse Asset Management', 'DNB Asset Management',
#         'DWS Investment', 'Daiwa Asset Management',
#         'Daiwa Asset Management ', 'Davis ETFs',
#         'Davy Global Fund Management', 'Day Hagan', 'Defiance ETFs',
#         'Deka Investment', 'DeltaShares', 'Democracy Investments',
#         'Desjardins Global Asset Management',
#         'Deutsche Bank Asset Management', 'Dimensional Fund Advisors',
#         'Direxion Funds', 'Distillate Capital Partners', 'EMQQ',
#         'ETF Management', 'ETRACS', 'Eaton Vance', 'Ecofin', 'Elements',
#         'Emles', 'EntrepreneurShares', 'Equbot', 'Equity Fund',
#         'Erste Asset Management', 'Esoterica Capital',
#         'Evolve Funds Group', 'Exchange Traded Concepts',
#         'Exponential ETFs', 'FT Portfolios', 'Falcom Financial Services',
#         'Fidelity Investments', 'FinEx Capital Management',
#         'Finance Portenetimi', 'First Financial Holding',
#         'First Trust Advisors', 'Fixed-Income Fund', 'Flexshares Trust',
#         'Focus Morningstar', 'FormulaFolioFunds', 'Frankfurter Volksbank',
#         'Franklink Templeton Investments',
#         'Fubon Securities Investment Trust', 'Fuchs Asset Management',
#         'Fuh Hwa Securities Investment Trust',
#         'FundRock Management Company', 'Fundlogic',
#         'GAM Investment Management', 'Gabelli', 'Generali Investments',
#         'Genlith', 'Global Beta', 'Global X Funds',
#         'Gold Bullion Securities', 'Goldman Sachs Asset Management',
#         'Gotham', 'Graniteshares', 'Guardian Capital Group', 'Guggenheim',
#         'Guinness Atkinson', 'HANetf Limited', 'HSBC Investment Funds',
#         'Hamilton Capital Partners', 'Handelsbanken Fonder',
#         'Hanwha Asset Management', 'Hartford Mutual Funds',
#         'Harvest Portfolios Group', 'Highland Funds', 'Horizon Kinetics',
#         'Horizons ETFs Management', 'Howard Capital Management',
#         'Hoya Capital Real Estate', 'Hull Tactical Funds', 'Humankind',
#         'IA Clarington Investments', 'Impact Shares', 'IndexIQ',
#         'Infusive', 'Innovation Shares', 'Innovator ETFs', 'Inspire',
#         'Invesco Investment Management', 'Investment Fund',
#         'JKO Asset Management', 'JPMorgan Asset Management',
#         'Janus Henderson', 'Jefferies', 'John Hancock',
#         'Julius Baer Precious Metals', 'Knowledge Leaders Capital',
#         'KraneShares', 'Krungthai Asset Management',
#         'LBBW Asset Management', 'LGIM Managers', 'LeaderShares',
#         'Leatherback', 'Legg Mason Global Asset Management', 'Leuthold',
#         'Leverage Shares', 'Lion Global Investors',
#         'Little Harbor Advisors', 'Loncar Investments', 'Lysander Funds',
#         'Lyxor International Asset Management',
#         'MFS Investment Management', 'Mackenzie Investments',
#         'Main Management ETFs', 'Mairs & Power',
#         'Manulife Investment Management', 'Merk Funds', 'Metaurus',
#         'Microsectors', 'Middlefield Limited',
#         'Milleis Investissements Funds', 'Mitsubishi Asset Management',
#         'Monarch Funds', 'Morgan Creek', 'Morgan Stanley Asset Management',
#         'Motley Fool', 'National Bank Investments', 'Nationwide',
#         'Natixis Funds', 'Nikko Asset Management',
#         'Nikko Asset Management ', 'Nomura Asset Management',
#         'Nomura Asset Management ', 'Nomura Europe Finance NV',
#         'Nordea Asset Management', 'Nordea Bank AB',
#         'Norinchukin Zenkyoren Asset Mgmt Co.,Ltd', 'Nuveen', 'OSSIAM',
#         'OSSIOM', 'Overlay Shares', 'PGIM Funds', 'PIMCO Global Advisors',
#         'PPTY', 'Pacer', 'Pacific Global', 'Peritus',
#         'Philip Capital Management', 'Pictet Asset Management',
#         'Picton Mahoney Asset Management', 'PineBridge Investments',
#         'Point Bridge Capital', 'Premise Capital',
#         'Principal Asset Management Berhad', 'Principal Funds',
#         'ProShares', 'Procure ETF Trust', 'Purpose Investments',
#         'QuantShares', 'RBC Global Asset Management',
#         'Rakuten Investment Management', 'Rareview Capital', 'Rayliant',
#         'Renaissance Capital', 'RiverFront Strategic Income Fund',
#         'Robeco Capital Growth Funds', 'Robo Global',
#         'Roundhill Investments', 'Russell Investment Management',
#         'SA1 Issuer', 'SABA ETF', 'SEB Investment Management', 'SG Issuer',
#         'SP Funds', 'SPAC', 'SRN Advisors', 'Samsung Asset Management',
#         'Samsung KODEX', 'Schroder International Selection Fund ',
#         'Schwab ETFs', 'Shares Investments', 'Shin Kong Investment Trust',
#         'Simplex Asset Management ', 'Simplify Asset Management',
#         'SinoPac Securities Investment Trust', 'Siren', 'SmartETFs',
#         'SoFi', 'Sofi', 'Sound ETF',
#         'Sparinvest SICAV - Ethical Global Value', 'Spinnaker ETF Trust',
#         'Sprott', 'Stance', 'State Street Global Advisors',
#         'Sterling Capital Funds', 'Strategy Shares', 'Structured Invest',
#         'Sumitomo Mitsui DS Asset Management', 'Swan',
#         'Swisscanto Fondsleitung', 'Swisscanto Fondsleitung AG', 'Syntax',
#         'T. Rowe Price', 'TD Asset Management', 'TMB Asset Management',
#         'Tabula Investment Management',
#         'Taishin Securities Investment Trust', 'Teucrium', 'Timothy Plan',
#         'Toews Corporation', 'Tortoise Capital Advisors', 'TrimTabs',
#         'TrueShares', 'Tuttle', 'U.S. Global Investors',
#         'UBS Asset Management', 'UC', 'USCF Investments',
#         'Uncommon Investment Advisors', 'Uni-President Asset Management',
#         'Upholdings', 'VanEck Asset Management',
#         'Vanguard Asset Management', 'VelocityShares', 'Victory Capital',
#         'Vident Financial', 'Virtus', 'Vitruvius SICAV', 'Volshares',
#         'Vontobel Fonds Services', 'WBI Investments', 'Wahed Invest',
#         'Warburg Invest Kapitalanlagegesellschaft mbH',
#         'WisdomTree Asset Management', 'Xtrackers',
#         'Yuanta Securities Investment Trust', 'Ziraat Bank',
#         'iM Global Partner', 'wShares'], dtype=object),
#  'exchange': array(['AMS', 'AQS', 'ASE', 'ASX', 'ATH', 'BER', 'BRU', 'BTS', 'BUD',
#         'CPH', 'DJI', 'DOH', 'DUS', 'EBS', 'FRA', 'GER', 'HAM', 'HAN',
#         'HEL', 'ICE', 'ISE', 'IST', 'JPX', 'KSC', 'LIS', 'LIT', 'LSE',
#         'MCE', 'MCX', 'MEX', 'MIL', 'MUN', 'NCM', 'NEO', 'NGM', 'NIM',
#         'NMS', 'NYQ', 'OSL', 'PAR', 'PCX', 'PNK', 'PRA', 'SAU', 'SES',
#         'SET', 'STO', 'TAI', 'TLV', 'TOR', 'TWO', 'VIE'], dtype=object)}

# %%
# Filtering 'category_group' for Information Technology
etfs_data = etfs.select(category_group='Information Technology')
# Displaying the first 5 rows of the filtered data
etfs_data.head()
# Out:
#                            name currency  \
# symbol
# ^ONEQ         FIDELITY COMMWLTH      USD
# ^PNQI        INVESCO EXCHG TRAD      USD
# ^PSCT        INVESCO EXCH TRDII      USD
# 00753L.TW      CTBC China 50 2X      TWD
# 00757.TW   UPAMC NYSE FANG+ ETF      TWD
#
#                                                      summary  \
# symbol
# ^ONEQ      The Fidelity Nasdaq Composite ETF seeks to tra...
# ^PNQI      The Invesco NASDAQ Internet ETF tracks the per...
# ^PSCT      The Invesco S&P SmallCap Information Technolog...
# 00753L.TW  The CTBC China 50 2X ETF aims to provide two t...
# 00757.TW   UPAMC NYSE FANG+ ETF aims to replicate the per...
#
#                    category_group   category  \
# symbol
# ^ONEQ      Information Technology  Large Cap
# ^PNQI      Information Technology        NaN
# ^PSCT      Information Technology  Small Cap
# 00753L.TW  Information Technology        NaN
# 00757.TW   Information Technology        NaN
#
#                                        family exchange
# symbol
# ^ONEQ                    Fidelity Investments      NIM
# ^PNQI           Invesco Investment Management      NIM
# ^PSCT           Invesco Investment Management      NIM
# 00753L.TW    CTBC Securities Investment Trust      TAI
# 00757.TW   Yuanta Securities Investment Trust      TAI

# %%
etfs_data.shape
# Out:
# (1297, 7)

# %%
etfs_data.isna().sum()
# Out:
# name                0
# currency            4
# summary            68
# category_group      0
# category          454
# family            130
# exchange            1
# dtype: int64

# %%
# grouping the data by 'category'
etfs_data.groupby('category', dropna=False).size().reset_index(name='count')
# Out:
#                   category  count
# 0                    Blend      3
# 1   Consumer Discretionary      1
# 2        Developed Markets    392
# 3         Emerging Markets    168
# 4                  Factors      8
# 5         Frontier Markets      3
# 6                   Growth     62
# 7                Large Cap     94
# 8                  Mid Cap      9
# 9                Small Cap     35
# 10              Technology     39
# 11                 Trading      9
# 12                   Value     20

# %% [markdown]
# Within the *"Information Technology"* will select only the two subcategories:
# *   Developed Markets
# *   Emerging Markets
# We analyse where these ETFs are exchanged

# %%
# Filtering the data for 'Developed Markets' and 'Emerging Markets' by Exchange
top15_exchanges = etfs_data[etfs_data['category'].isin(['Developed Markets', 'Emerging Markets'])] \
    .groupby(['exchange'], dropna=False).size().reset_index(name='count').sort_values(by='count', ascending=False).reset_index(drop=True)
top15_exchanges
# Out:
#    exchange  count
# 0       FRA     70
# 1       BER     68
# 2       MUN     59
# 3       DUS     56
# 4       LSE     55
# 5       GER     40
# 6       EBS     35
# 7       PCX     27
# 8       HAM     27
# 9       MIL     27
# 10      MEX     17
# 11      PAR     17
# 12      TOR     15
# 13      AMS     13
# 14      HAN      8
# 15      MCX      6
# 16      NMS      5
# 17      BTS      5
# 18      KSC      4
# 19      JPX      3
# 20      ASX      1
# 21      NGM      1
# 22      SET      1

# %% [markdown]
# There are 23 exchanges, we decide to keep only the 15 most significant ones

# %%
top15_exchanges_list = top15_exchanges['exchange'].head(15).tolist()
top15_exchanges_list
# Out:
# ['FRA',
#  'BER',
#  'MUN',
#  'DUS',
#  'LSE',
#  'GER',
#  'EBS',
#  'PCX',
#  'HAM',
#  'MIL',
#  'MEX',
#  'PAR',
#  'TOR',
#  'AMS',
#  'HAN']

# %% [markdown]
# We can now make a new selection

# %%
# Obtaining Information Technology ETFs categorized as Emerging Markets or Developed markets from top 15 exchanges
tech_etfs = etfs.select(
    category_group='Information Technology',
    category=['Developed Markets', 'Emerging Markets'],
    exchange=top15_exchanges_list
)
# counting the number of ETFs by category and exchange in a pivot table
tech_etfs_pivot = tech_etfs_count.pivot(index='exchange', columns='category', values='count').fillna(0).astype(int)

# Adding totals for rows and columns
tech_etfs_pivot['Total'] = tech_etfs_pivot.sum(axis=1)
tech_etfs_pivot.loc['Total'] = tech_etfs_pivot.sum(axis=0)

tech_etfs_pivot
# Out:
# category  Developed Markets  Emerging Markets  Total
# exchange
# AMS                      11                 2     13
# BER                      43                25     68
# DUS                      35                21     56
# EBS                      29                 6     35
# FRA                      49                21     70
# GER                      33                 7     40
# HAM                      17                10     27
# HAN                       3                 5      8
# LSE                      39                16     55
# MEX                      13                 4     17
# MIL                      22                 5     27
# MUN                      35                24     59
# PAR                      14                 3     17
# PCX                      14                13     27
# TOR                      15                 0     15
# Total                   372               162    534

# %% [markdown]
# We obtain a total of 534 ETFS traded in 15 Exchanges with approximately 70% categorized as developed markets and 30% as emerging markets
# We can build our list of ETFs

# %%
tech_etfs
# Out:
#                                                      name currency  \
# symbol
# 018F.BE                         ISHS INC-MSCI MALYSIA NEW      EUR
# 0253.BE                         VANGUA.ESG INTL STOCK ETF      EUR
# 0254.BE                         VANGUAR.ESG U.S.STOCK ETF      EUR
# 025C.BE                           VANG.EMERG.M.ST.IDX ETF      EUR
# 025M.BE                           VANG.TOT.INT.ST.IDX ETF      EUR
# ...                                                   ...      ...
# XWLD.L                  Xtrackers MSCI World UCITS ETF 1C      GBP
# ZPDT.BE                         SPDR S+P US TECH.S.S.UETF      EUR
# ZPDT.DE  SPDR S&P U.S. Technology Select Sector UCITS ETF      EUR
# ZPDT.DU                         SPDR S+P US TECH.S.S.UETF      EUR
# ZPDT.F   SPDR S&P U.S. Technology Select Sector UCITS ETF      EUR
#
#                                                    summary  \
# symbol
# 018F.BE  ISHS INC-MSCI MALYSIA NEW is an iShares ETF pr...
# 0253.BE  VANGUA.ESG INTL STOCK ETF is a Vanguard ETF fo...
# 0254.BE  VANGUAR.ESG U.S.STOCK ETF is a Vanguard ETF th...
# 025C.BE  VANG.EMERG.M.ST.IDX ETF is a Vanguard ETF that...
# 025M.BE  VANG.TOT.INT.ST.IDX ETF is a Vanguard ETF that...
# ...                                                    ...
# XWLD.L   The aim is for the investment to reflect the p...
# ZPDT.BE  SPDR S+P US TECH.S.S.UETF is an exchange-trade...
# ZPDT.DE  The objective of the SPDR S&P U.S. Technology ...
# ZPDT.DU  SPDR S+P US TECH.S.S.UETF is an exchange-trade...
# ZPDT.F   The objective of the SPDR S&P U.S. Technology ...
#
#                  category_group           category  \
# symbol
# 018F.BE  Information Technology   Emerging Markets
# 0253.BE  Information Technology  Developed Markets
# 0254.BE  Information Technology  Developed Markets
# 025C.BE  Information Technology   Emerging Markets
# 025M.BE  Information Technology  Developed Markets
# ...                         ...                ...
# XWLD.L   Information Technology  Developed Markets
# ZPDT.BE  Information Technology  Developed Markets
# ZPDT.DE  Information Technology  Developed Markets
# ZPDT.DU  Information Technology  Developed Markets
# ZPDT.F   Information Technology  Developed Markets
#
#                                family exchange
# symbol
# 018F.BE    BlackRock Asset Management      BER
# 0253.BE     Vanguard Asset Management      BER
# 0254.BE     Vanguard Asset Management      BER
# 025C.BE     Vanguard Asset Management      BER
# 025M.BE     Vanguard Asset Management      BER
# ...                               ...      ...
# XWLD.L                      Xtrackers      LSE
# ZPDT.BE  State Street Global Advisors      BER
# ZPDT.DE  State Street Global Advisors      GER
# ZPDT.DU  State Street Global Advisors      DUS
# ZPDT.F   State Street Global Advisors      FRA
#
# [534 rows x 7 columns]

# %%
tech_etfs_list = tech_etfs.index.tolist()
tech_etfs_list
# Out:
# ['018F.BE',
#  '0253.BE',
#  '0254.BE',
#  '025C.BE',
#  '025M.BE',
#  '2B79.DE',
#  '2B79.F',
#  'AH50.DE',
#  'AH50.DU',
#  'AH50.F',
#  'AH50.L',
#  'AH50.MU',
#  'AH80.BE',
#  'AH80.DU',
#  'AH80.F',
#  'AH80.HM',
#  'AH80.MU',
#  'AH81.BE',
#  'AH81.DU',
#  'AH81.F',
#  'AH81.HM',
#  'AH81.MU',
#  'AH82.BE',
#  'AH82.DU',
#  'AH82.F',
#  'AH82.HM',
#  'AH82.MU',
#  'AH83.BE',
#  'AH83.MU',
#  'AH87.MU',
#  'AH89.BE',
#  'AH89.DU',
#  'AH89.F',
#  'AH89.MU',
#  'AH8H.DU',
#  'AH8H.F',
#  'AH8H.HM',
#  'AH8H.MU',
#  'AH8J.BE',
#  'AH8J.DU',
#  'AH8J.F',
#  'AH8J.MU',
#  'AH8P.HM',
#  'AH8R.DU',
#  'AH8R.F',
#  'AH8U.MU',
#  'AH8V.BE',
#  'AH8V.DU',
#  'AH8V.F',
#  'AH8V.HM',
#  'AH8V.MU',
#  'BUNH.DE',
#  'BUNH.DU',
#  'BUNH.F',
#  'BUZZ',
#  'CBUSA-USD.SW',
#  'CBUSA.SW',
#  'CC1.MI',
#  'CC1.PA',
#  'CC1E.SW',
#  'CC1G.L',
#  'CC1U.L',
#  'CC1U.PA',
#  'CC1USD.SW',
#  'CCAU.L',
#  'CCAUN.MX',
#  'CCEI.TO',
#  'CD47.BE',
#  'CD47.DE',
#  'CD47.DU',
#  'CD47.F',
#  'CD47.HM',
#  'CD47.MU',
#  'CD5.PA',
#  'CD5E.SW',
#  'CD8.PA',
#  'CD9.PA',
#  'CE2D.L',
#  'CE8.PA',
#  'CE8E.SW',
#  'CE8G.DE',
#  'CFPM.F',
#  'CHIK',
#  'CHIK.MX',
#  'CQQQ',
#  'DGTL.L',
#  'DGTL.MI',
#  'DGTL.SW',
#  'DGTLN.MX',
#  'DXSH.BE',
#  'DXSH.DE',
#  'DXSH.DU',
#  'DXSH.F',
#  'DXSH.HM',
#  'DXSH.MU',
#  'EMQQ.DE',
#  'EMQQ.DU',
#  'EMQQ.F',
#  'EMQQ.L',
#  'EMQQ.MI',
#  'EMQQ.MU',
#  'EMQQ.SW',
#  'ETLH.BE',
#  'ETLH.DE',
#  'ETLH.DU',
#  'ETLH.F',
#  'ETLH.MU',
#  'EXIB.DE',
#  'EXIB.MU',
#  'EXS2.BE',
#  'EXS2.DE',
#  'EXS2.DU',
#  'EXS2.F',
#  'EXS2.HM',
#  'EXS2.MU',
#  'EXXT.BE',
#  'EXXT.DE',
#  'EXXT.DU',
#  'EXXT.F',
#  'EXXT.HM',
#  'EXXT.MU',
#  'FCBR.L',
#  'FHQ.TO',
#  'FIWD.BE',
#  'FJ2P.F',
#  'FPIF.BE',
#  'FPIF.DU',
#  'FPIF.F',
#  'FPIF.MU',
#  'FPIG.BE',
#  'FPIG.DU',
#  'FPIG.F',
#  'FSKY.L',
#  'FSKY.MI',
#  'FTG5.BE',
#  'FTG5.DU',
#  'FTGC.MU',
#  'FXP',
#  'FYEM.DE',
#  'FYEM.F',
#  'FYEQ.DE',
#  'FYEQ.F',
#  'FYER.DE',
#  'FYER.F',
#  'FZ14.BE',
#  'FZ14.DU',
#  'FZ14.F',
#  'FZ14.HM',
#  'FZ14.MU',
#  'FZ17.BE',
#  'FZ17.DU',
#  'FZ17.F',
#  'FZ17.HM',
#  'FZ17.MU',
#  'FZ1E.BE',
#  'FZ1E.DU',
#  'FZ1E.F',
#  'FZ1E.HM',
#  'FZ1E.MU',
#  'FZ1H.BE',
#  'FZ1H.F',
#  'FZ1H.MU',
#  'GEQ0.BE',
#  'IBCY.BE',
#  'IBCY.DE',
#  'IBCY.DU',
#  'IBCY.F',
#  'IBCZ.BE',
#  'IBCZ.DE',
#  'IBCZ.DU',
#  'IBCZ.F',
#  'IDKO.L',
#  'IDLV',
#  'IDMO',
#  'IDNA.L',
#  'IDTK.L',
#  'IDTW.L',
#  'IDTWN.MX',
#  'IDWR.L',
#  'IDX',
#  'IEEM.L',
#  'IEEM.MI',
#  'IEEM.SW',
#  'IEER.AS',
#  'IEER.L',
#  'IEER.SW',
#  'IEEU.L',
#  'IEFA.MX',
#  'IEFM.L',
#  'IEFQ.L',
#  'IEFS.L',
#  'IS4S.DE',
#  'IS4S.F',
#  'ISEC.BE',
#  'ISED.AS',
#  'ISEE.MU',
#  'ISEU.L',
#  'ISFR.L',
#  'ISPY.AS',
#  'ISPY.L',
#  'ISPY.MI',
#  'ISPY.SW',
#  'ISQA.BE',
#  'ISQA.MU',
#  'ISQL.BE',
#  'ISQM.BE',
#  'ISQM.MU',
#  'ISQN.BE',
#  'ISQP.BE',
#  'ISQX.BE',
#  'ISQX.MU',
#  'ISRA',
#  'ISRL.L',
#  'ISTM.DE',
#  'ISTM.F',
#  'ISTM.PA',
#  'ISUS.L',
#  'ISV0.BE',
#  'ISV1.BE',
#  'ISV3.BE',
#  'ISV3.MU',
#  'ISV5.BE',
#  'ITEQ',
#  'JAPA.SW',
#  'JAPN-B.TO',
#  'JAPN.TO',
#  'JARH.DE',
#  'JARH.F',
#  'JARI.DE',
#  'JARI.F',
#  'JARI.L',
#  'JCTR',
#  'JHMT',
#  'KEMQ',
#  'KFTK.BE',
#  'KFTK.DE',
#  'KFTK.DU',
#  'KFTK.F',
#  'KFTK.MU',
#  'KFVG',
#  'KGRN',
#  'KSTR',
#  'KWBE.L',
#  'KWBP.L',
#  'KWEB',
#  'KWEB.AS',
#  'KWEB.L',
#  'KWEB.MI',
#  'KWEB.MX',
#  'L0CK.DE',
#  'L0CK.F',
#  'LOCK.L',
#  'LOCK.MI',
#  'LOCK.SW',
#  'LTUG.DE',
#  'LTUG.F',
#  'LYMS.BE',
#  'LYMS.DE',
#  'LYMS.DU',
#  'LYMS.F',
#  'LYMS.HM',
#  'LYMS.MU',
#  'LYPG.BE',
#  'LYPG.DE',
#  'LYPG.DU',
#  'LYPG.F',
#  'LYPG.HM',
#  'LYPG.MU',
#  'LYTNOW.SW',
#  'MUS.PA',
#  'MUS.TO',
#  'MUSRI.MI',
#  'MUSRI.PA',
#  'MUUSAS.SW',
#  'MVAE.MI',
#  'MVAE.PA',
#  'MVAU.MI',
#  'MVAU.PA',
#  'MVEA.AS',
#  'MVEA.DE',
#  'MVEA.DU',
#  'MVEA.F',
#  'MVEA.L',
#  'MVEA.MU',
#  'MVEA.SW',
#  'MVEC.SW',
#  'MVED.L',
#  'MVEE.BE',
#  'MVEE.DE',
#  'MVEE.DU',
#  'MVEE.F',
#  'MVEE.L',
#  'MVEE.MU',
#  'MVEE.SW',
#  'MVEU.L',
#  'MVEU.MI',
#  'MVEU.SW',
#  'MVEUN.MX',
#  'MVEW.AS',
#  'MVEW.DE',
#  'MVEW.DU',
#  'MVEW.F',
#  'MVEW.L',
#  'MVEW.MU',
#  'MVEW.SW',
#  'MVEWN.MX',
#  'MVLD.AS',
#  'MVOL.L',
#  'MVOL.MI',
#  'MVOL.SW',
#  'MVSH.SW',
#  'MVUS.L',
#  'MVUS.MI',
#  'MVUS.PA',
#  'MVUS.SW',
#  'MVWE.SW',
#  'MWD.TO',
#  'OM3L.DE',
#  'OM3L.F',
#  'ORBT-U.TO',
#  'ORBT.TO',
#  'PIMV.F',
#  'PIMX.BE',
#  'PIMX.DU',
#  'PIMX.HM',
#  'PIMX.MU',
#  'PIN',
#  'PINR.PA',
#  'RK10.BE',
#  'RK10.DU',
#  'RK10.MU',
#  'RK11.BE',
#  'RK11.DU',
#  'RK11.F',
#  'RK11.HA',
#  'RK11.HM',
#  'RK11.MU',
#  'RK12.BE',
#  'RK12.DU',
#  'RK12.F',
#  'RK12.HA',
#  'RK12.HM',
#  'RK12.MU',
#  'RK13.BE',
#  'RK13.DU',
#  'RK13.F',
#  'RK13.HA',
#  'RK13.HM',
#  'RK13.MU',
#  'RK14.BE',
#  'RK14.DU',
#  'RK14.F',
#  'RK14.HM',
#  'RK14.MU',
#  'RK15.BE',
#  'RK15.DU',
#  'RK15.F',
#  'RK15.HM',
#  'RK15.MU',
#  'RK18.BE',
#  'RK18.DU',
#  'RK18.F',
#  'RK18.MU',
#  'RK1B.BE',
#  'RK1B.DU',
#  'RK1B.F',
#  'RK1B.HA',
#  'RK1B.HM',
#  'RK1B.MU',
#  'RK1C.BE',
#  'RK1C.DU',
#  'RK1C.F',
#  'RK1C.HA',
#  'RK1C.HM',
#  'RK1C.MU',
#  'SPYK.BE',
#  'SPYK.DE',
#  'SPYK.DU',
#  'SPYK.F',
#  'SPYK.MU',
#  'SS47.BE',
#  'SS47.DU',
#  'SSGI.BE',
#  'SSGI.HM',
#  'STK.PA',
#  'STKX.MI',
#  'STKX.SW',
#  'STXH.DE',
#  'STXH.F',
#  'SUAS.L',
#  'SUAS.MI',
#  'SUAS.SW',
#  'SUASN.MX',
#  'SUES.L',
#  'SUJA.L',
#  'SUJD.AS',
#  'SUJP.L',
#  'SUJP.MI',
#  'SUJP.SW',
#  'SUJPN.MX',
#  'SUJS.L',
#  'SUSA',
#  'SUSA.MX',
#  'SUSA.TO',
#  'SUSM.L',
#  'SUSM.MI',
#  'SUSM.SW',
#  'SUSMN.MX',
#  'SUSW.L',
#  'SUSW.MI',
#  'SUSW.SW',
#  'SUUS.L',
#  'SUWG.L',
#  'SUWS.L',
#  'SUWSN.MX',
#  'SUWU.AS',
#  'SUWU.SW',
#  'SVE.MI',
#  'TCLV.TO',
#  'TDIV.AS',
#  'TDIV.L',
#  'TDIV.MI',
#  'TDIV.SW',
#  'TDL1.MU',
#  'TDL8.BE',
#  'TDL8.DU',
#  'TDL8.F',
#  'TDL8.MU',
#  'TDLB.BE',
#  'TDLB.DU',
#  'TDLB.F',
#  'TDLB.MU',
#  'TDLF.BE',
#  'TDLF.DU',
#  'TDLF.F',
#  'TDLF.MU',
#  'TDLP.BE',
#  'TDLP.DU',
#  'TDLP.MU',
#  'TDLQ.BE',
#  'TDLQ.DU',
#  'TDLQ.F',
#  'TDLQ.MU',
#  'TDT.AS',
#  'TDXPEX.SW',
#  'TEC.TO',
#  'TECB',
#  'TECL',
#  'TECL.MX',
#  'TECS',
#  'TECS.MX',
#  'TEET.AS',
#  'TEP1.BE',
#  'TEP1.DU',
#  'TEP1.F',
#  'TEP1.HA',
#  'TEP1.HM',
#  'TEP1.MU',
#  'TEP3.BE',
#  'TEP3.DU',
#  'TEP3.F',
#  'TEP3.HA',
#  'TEP3.HM',
#  'TEP3.MU',
#  'TEP5.BE',
#  'TEP5.DU',
#  'TEP5.F',
#  'TEP5.HA',
#  'TEP5.HM',
#  'TEP5.MU',
#  'TEP6.BE',
#  'TEP6.DU',
#  'TLF-U.TO',
#  'TLF.TO',
#  'TLTD',
#  'TLTE',
#  'TNO.MI',
#  'TNO.PA',
#  'TNOD.SW',
#  'TNOW.L',
#  'TNOW.MI',
#  'TNOW.PA',
#  'TPAY',
#  'UIC1.DE',
#  'UIC1.DU',
#  'UIC1.F',
#  'UIC1.MU',
#  'UIC2.DE',
#  'UIC2.DU',
#  'UIC2.F',
#  'UIC2.MU',
#  'UNIC.L',
#  'UNIC.MI',
#  'UNIC.PA',
#  'USD',
#  'VGT',
#  'VGT.MX',
#  'VVGM.BE',
#  'VVGM.DE',
#  'VVGM.DU',
#  'VVGM.F',
#  'VVGM.MU',
#  'VVSM.BE',
#  'VVSM.DE',
#  'VVSM.DU',
#  'VVSM.F',
#  'VVSM.MU',
#  'WITS.AS',
#  'WITS.SW',
#  'XDWT.DE',
#  'XDWT.F',
#  'XDWT.L',
#  'XDWT.MI',
#  'XIT.TO',
#  'XITK',
#  'XSTC.L',
#  'XT.MX',
#  'XUTC.DE',
#  'XUTC.F',
#  'XUTC.L',
#  'XUTC.MI',
#  'XUTC.SW',
#  'XVTD.L',
#  'XWD.TO',
#  'XWD1.DE',
#  'XWD1.F',
#  'XWEH.DE',
#  'XWEH.F',
#  'XWEH.MI',
#  'XWLD.L',
#  'ZPDT.BE',
#  'ZPDT.DE',
#  'ZPDT.DU',
#  'ZPDT.F']

# %% [markdown]
# We need to remove duplicate ETFs which are traded in multiple exchanges, like
#  *   'AH81.BE',
#  *  'AH81.DU',
#  *  'AH81.F',
#  *  'AH81.HM',
#  *  'AH81.MU',
