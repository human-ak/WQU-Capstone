# %%
import tensorflow as tf
import numpy as np
import random
import os
import pickle
import gc

# Reproducibility
seed = 42
os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# Optional: disable eager execution (if using graph mode code)
#tf.compat.v1.disable_eager_execution()

# Session config
session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1,
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(config=session_conf)

# Set this session as default for everything that follows
# No set_session needed — use a context manager instead
with sess.as_default():
    # your model/code here
    pass

tf.__version__
# Out:
# 2025-05-19 11:17:31.563125: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-19 11:17:31.573036: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747653451.584659  597182 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747653451.588415  597182 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747653451.597474  597182 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747653451.597498  597182 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747653451.597499  597182 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747653451.597500  597182 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-19 11:17:31.601147: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1747653453.769185  597182 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9706 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# '2.19.0'

# %%
os.getcwd()
# Out:
# '/mnt/c/Users/ansel/AppData/Local/Programs/Microsoft VS Code'

# %%
os.chdir('/mnt/d/GitHub/WQU-Capstone/notebooks/classes')

os.getcwd()
# Out:
# '/mnt/d/GitHub/WQU-Capstone/notebooks/classes'

# %% [markdown]
# ### Import Classes

# %%
# %load_ext autoreload
# %aimport class_ForecastingTrader 
# %autoreload 1
# Out:
# I0000 00:00:1747653453.863449  597182 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9706 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# series_analyser = class_SeriesAnalyser.SeriesAnalyser()
# trader = class_Trader.Trader()
# data_processor = class_DataProcessor.DataProcessor()
forecasting_trader = class_ForecastingTrader.ForecastingTrader()

# %%
current_path='/mnt/d/GitHub/WQU-Capstone/notebooks/PCA_75etf'
with open(f'{current_path}/PCA_selected_pairs.pickle', 'rb') as handle: 
    pairs = pickle.load(handle)
len(pairs)
# Out:
# 9

# %% [markdown]
# ## model train

# %%
n_in_set = [24, 12, 6]
hidden_nodes_set = [[50], [30], [10]]

hidden_nodes_names = [str(nodes[0])+'*2' if len(nodes) > 1 else str(nodes[0]) for nodes in hidden_nodes_set]

# %%
for input_dim in n_in_set:
    for i, hidden_nodes in enumerate(hidden_nodes_set):
        model_config = {"n_in": input_dim,
                        "n_out": 1,
                        "epochs": 500,
                        "hidden_nodes": hidden_nodes,
                        "loss_fct": "mse",
                        "optimizer": "rmsprop",
                        "batch_size": 256,
                        "train_val_split": '2023-01-01',
                        "test_init": '2024-01-01',}
        models = forecasting_trader.train_models(pairs, model_config, model_type='mlp')
        # save models for this configuration
        with open(f'{current_path}/models/mlp/models_n_in-'+str(input_dim)+'_hidden_nodes-'+hidden_nodes_names[i]+'.pkl', 'wb') as f:
            pickle.dump(models, f)

gc.collect()
# Out:
# /home/ansel/miniconda3/envs/tf/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1747653453.960746  597182 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9706 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 50)             │         1,250 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,301 (5.08 KB)
#  Trainable params: 1,301 (5.08 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747653455.051419  597241 service.cc:152] XLA service 0x7f2e400198e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747653455.051457  597241 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-05-19 11:17:35.067133: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1747653455.111098  597241 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 2s 583ms/step - loss: 0.1583 - mae: 0.3124
# I0000 00:00:1747653455.285784  597241 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.2705 - mae: 0.3927 - val_loss: 0.1811 - val_mae: 0.3308
# Epoch 2/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.
500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0268 - mae: 0.1264 - val_loss: 0.0681 - val_mae: 0.2090
# Epoch 112/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0272 - mae: 0.1242 - val_loss: 0.0619 - val_mae: 0.2045
# Epoch 113/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0267 - mae: 0.1261 - val_loss: 0.0678 - val_mae: 0.2084
# Epoch 114/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0270 - mae: 0.1238 - val_loss: 0.0619 - val_mae: 0.2045
# Epoch 115/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0266 - mae: 0.1259 - val_loss: 0.0677 - val_mae: 0.2083
# Epoch 116/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0269 - mae: 0.1236 - val_loss: 0.0613 - val_mae: 0.2035
# Epoch 117/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0265 - mae: 0.1257 - val_loss: 0.0674 - val_mae: 0.2078
# Epoch 118/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0268 - mae: 0.1234 - val_loss: 0.0611 - val_mae: 0.2031
# Epoch 119/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0263 - mae: 0.1253 - val_loss: 0.0675 - val_mae: 0.2080
# Epoch 120/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0268 - mae: 0.1233 - val_loss: 0.0610 - val_mae: 0.2030
# Epoch 121/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0263 - mae: 0.1251 - val_loss: 0.0670 - val_mae: 0.2073
# Epoch 122/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0267 - mae: 0.1230 - val_loss: 0.0605 - val_mae: 0.2022
# Epoch 123/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0261 - mae: 0.1249 - val_loss: 0.0666 - val_mae: 0.2066
# Epoch 124/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0266 - mae: 0.1228 - val_loss: 0.0602 - val_mae: 0.2016
# Epoch 125/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0260 - mae: 0.1246 - val_loss: 0.0664 - val_mae: 0.2063
# Epoch 126/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0265 - mae: 0.1226 - val_loss: 0.0595 - val_mae: 0.2005
# Epoch 127/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0259 - mae: 0.1243 - val_loss: 0.0659 - val_mae: 0.2054
# Epoch 128/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0263 - mae: 0.1223 - val_loss: 0.0593 - val_mae: 0.2003
# Epoch 129/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0258 - mae: 0.1242 - val_loss: 0.0657 - val_mae: 0.2051
# Epoch 130/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0263 - mae: 0.1221 - val_loss: 0.0591 - val_mae: 0.2001
# Epoch 131/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0257 - mae: 0.1241 - val_loss: 0.0649 - val_mae: 0.2038
# Epoch 132/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0261 - mae: 0.1217 - val_loss: 0.0590 - val_mae: 0.2000
# Epoch 133/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0257 - mae: 0.1240 - val_loss: 0.0643 - val_mae: 0.2028
# Epoch 134/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0260 - mae: 0.1213 - val_loss: 0.0590 - val_mae: 0.2001
# Epoch 135/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0256 - mae: 0.1240 - val_loss: 0.0641 - val_mae: 0.2025
# Epoch 136/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0259 - mae: 0.1211 - val_loss: 0.0591 - val_mae: 0.2002
# Epoch 137/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0256 - mae: 0.1238 - val_loss: 0.0639 - val_mae: 0.2021
# Epoch 138/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0258 - mae: 0.1210 - val_loss: 0.0591 - val_mae: 0.2004
# Epoch 139/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0255 - mae: 0.1238 - val_loss: 0.0638 - val_mae: 0.2019
# Epoch 140/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0257 - mae: 0.1208 - val_loss: 0.0588 - val_mae: 0.1998
# Epoch 141/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0254 - mae: 0.1236 - val_loss: 0.0635 - val_mae: 0.2015
# Epoch 142/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0257 - mae: 0.1206 - val_loss: 0.0588 - val_mae: 0.1999
# Epoch 143/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0254 - mae: 0.1235 - val_loss: 0.0633 - val_mae: 0.2012
# Epoch 144/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.
500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0245 - mae: 0.1213 - val_loss: 0.0611 - val_mae: 0.1974
# Epoch 178/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0247 - mae: 0.1182 - val_loss: 0.0568 - val_mae: 0.1968
# Epoch 179/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0244 - mae: 0.1210 - val_loss: 0.0606 - val_mae: 0.1965
# Epoch 180/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0246 - mae: 0.1180 - val_loss: 0.0570 - val_mae: 0.1971
# Epoch 181/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0244 - mae: 0.1211 - val_loss: 0.0605 - val_mae: 0.1964
# Epoch 182/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0245 - mae: 0.1178 - val_loss: 0.0569 - val_mae: 0.1970
# Epoch 183/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0244 - mae: 0.1210 - val_loss: 0.0605 - val_mae: 0.1964
# Epoch 184/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0245 - mae: 0.1177 - val_loss: 0.0569 - val_mae: 0.1970
# Epoch 185/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0243 - mae: 0.1210 - val_loss: 0.0604 - val_mae: 0.1963
# Epoch 186/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0244 - mae: 0.1176 - val_loss: 0.0565 - val_mae: 0.1963
# Epoch 187/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0242 - mae: 0.1206 - val_loss: 0.0601 - val_mae: 0.1957
# Epoch 188/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0244 - mae: 0.1175 - val_loss: 0.0567 - val_mae: 0.1967
# Epoch 189/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0242 - mae: 0.1207 - val_loss: 0.0602 - val_mae: 0.1958
# Epoch 190/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0244 - mae: 0.1174 - val_loss: 0.0566 - val_mae: 0.1966
# Epoch 191/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0242 - mae: 0.1206 - val_loss: 0.0600 - val_mae: 0.1955
# Epoch 192/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0243 - mae: 0.1173 - val_loss: 0.0562 - val_mae: 0.1959
# Epoch 193/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0241 - mae: 0.1204 - val_loss: 0.0598 - val_mae: 0.1952
# Epoch 194/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0243 - mae: 0.1172 - val_loss: 0.0563 - val_mae: 0.1960
# Epoch 195/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0241 - mae: 0.1204 - val_loss: 0.0598 - val_mae: 0.1953
# Epoch 196/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0242 - mae: 0.1172 - val_loss: 0.0563 - val_mae: 0.1960
# Epoch 197/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0241 - mae: 0.1204 - val_loss: 0.0597 - val_mae: 0.1951
# Epoch 198/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0242 - mae: 0.1170 - val_loss: 0.0561 - val_mae: 0.1956
# Epoch 199/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0240 - mae: 0.1202 - val_loss: 0.0593 - val_mae: 0.1942
# Epoch 200/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0241 - mae: 0.1168 - val_loss: 0.0560 - val_mae: 0.1956
# Epoch 201/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0240 - mae: 0.1203 - val_loss: 0.0592 - val_mae: 0.1942
# Epoch 202/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0241 - mae: 0.1167 - val_loss: 0.0560 - val_mae: 0.1956
# Epoch 203/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0240 - mae: 0.1202 - val_loss: 0.0592 - val_mae: 0.1942
# Epoch 204/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0241 - mae: 0.1167 - val_loss: 0.0560 - val_mae: 0.1956
# Epoch 205/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0240 - mae: 0.1201 - val_loss: 0.0589 - val_mae: 0.1936
# Epoch 206/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0240 - mae: 0.1165 - val_loss: 0.0560 - val_mae: 0.1955
# Epoch 207/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0239 - mae: 0.1200 - val_loss: 0.0589 - val_mae: 0.1936
# Epoch 208/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0240 - mae: 0.1165 - val_loss: 0.0558 - val_mae: 0.1952
# Epoch 209/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0239 - mae: 0.1199 - val_loss: 0.0587 - val_mae: 0.1932
# Epoch 210/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0239 - mae: 0.1163 - val_loss: 0.0557 - val_mae: 0.1950
# Epoch 211/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.
500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0220 - mae: 0.1149 - val_loss: 0.0497 - val_mae: 0.1773
# Epoch 378/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0216 - mae: 0.1105 - val_loss: 0.0518 - val_mae: 0.1878
# Epoch 379/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0219 - mae: 0.1148 - val_loss: 0.0495 - val_mae: 0.1770
# Epoch 380/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0216 - mae: 0.1103 - val_loss: 0.0515 - val_mae: 0.1874
# Epoch 381/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0219 - mae: 0.1147 - val_loss: 0.0497 - val_mae: 0.1773
# Epoch 382/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0216 - mae: 0.1105 - val_loss: 0.0513 - val_mae: 0.1868
# Epoch 383/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0218 - mae: 0.1145 - val_loss: 0.0493 - val_mae: 0.1765
# Epoch 384/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0216 - mae: 0.1104 - val_loss: 0.0513 - val_mae: 0.1870
# Epoch 385/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0219 - mae: 0.1146 - val_loss: 0.0494 - val_mae: 0.1767
# Epoch 386/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0216 - mae: 0.1103 - val_loss: 0.0512 - val_mae: 0.1868
# Epoch 387/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0218 - mae: 0.1145 - val_loss: 0.0494 - val_mae: 0.1767
# Epoch 388/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0216 - mae: 0.1103 - val_loss: 0.0514 - val_mae: 0.1870
# Epoch 389/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0218 - mae: 0.1145 - val_loss: 0.0493 - val_mae: 0.1766
# Epoch 390/500
# ...
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# ------------------------------------------------------------
# The mse train loss is:  0.033094216138124466
# The mse test loss is:  0.05616039037704468
# ------------------------------------------------------------
# /home/ansel/miniconda3/envs/tf/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_40 (Dense)                │ (None, 10)             │           250 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 261 (1.02 KB)
#  Trainable params: 261 (1.02 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 1.5009 - mae: 0.9365 - val_loss: 3.7462 - val_mae: 1.5630
# Epoch 2/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9107 - mae: 0.7279 - val_loss: 2.3597 - val_mae: 1.2479
# Epoch 3/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6449 - mae: 0.6138 - val_loss: 1.5004 - val_mae: 1.0003
# Epoch 4/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4768 - mae: 0.5309 - val_loss: 0.9656 - val_mae: 0.8004
# Epoch 5/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3667 - mae: 0.4712 - val_loss: 0.6426 - val_mae: 0.6435
# Epoch 6/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2935 - mae: 0.4265 - val_loss: 0.4605 - val_mae: 0.5353
# Epoch 7/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2445 - mae: 0.3919 - val_loss: 0.3624 - val_mae: 0.4661
# Epoch 8/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2101 - mae: 0.3649 - val_loss: 0.3093 - val_mae: 0.4259
# Epoch 9/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1849 - mae: 0.3431 - val_loss: 0.2801 - val_mae: 0.4025
# Epoch 10/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1661 - mae: 0.3250 - val_loss: 0.2619 - val_mae: 0.3873
# Epoch 11/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1523 - mae: 0.3099 - val_loss: 0.2488 - val_mae: 0.3761
# Epoch 12/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1423 - mae: 0.2983 - val_loss: 0.2368 - val_mae: 0.3660
# Epoch 13/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1349 - mae: 0.2894 - val_loss: 0.2255 - val_mae: 0.3569
# Epoch 14/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1289 - mae: 0.2823 - val_loss: 0.2163 - val_mae: 0.3502
# Epoch 15/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1239 - mae: 0.2765 - val_loss: 0.2065 - val_mae: 0.3431
# Epoch 16/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1192 - mae: 0.2711 - val_loss: 0.1981 - val_mae: 0.3367
# Epoch 17/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1149 - mae: 0.2658 - val_loss: 0.1894 - val_mae: 0.3301
# Epoch 18/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1106 - mae: 0.2606 - val_loss: 0.1823 - val_mae: 0.3245
# Epoch 19/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1066 - mae: 0.2556 - val_loss: 0.1744 - val_mae: 0.3181
# Epoch 20/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1028 - mae: 0.2507 - val_loss: 0.1678 - val_mae: 0.3127
# Epoch 21/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0992 - mae: 0.2461 - val_loss: 0.1608 - val_mae: 0.3069
# Epoch 22/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0959 - mae: 0.2418 - val_loss: 0.1554 - val_mae: 0.3025
# Epoch 23/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0928 - mae: 0.2377 - val_loss: 0.1516 - val_mae: 0.2991
# Epoch 24/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0901 - mae: 0.2341 - val_loss: 0.1464 - val_mae: 0.2945
# Epoch 25/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0874 - mae: 0.2305 - val_loss: 0.1420 - val_mae: 0.2904
# Epoch 26/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0849 - mae: 0.2272 - val_loss: 0.1366 - val_mae: 0.2851
# Epoch 27/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0824 - mae: 0.2238 - val_loss: 0.1320 - val_mae: 0.2804
# Epoch 28/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0801 - mae: 0.2206 - val_loss: 0.1277 - val_mae: 0.2760
# Epoch 29/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0779 - mae: 0.2177 - val_loss: 0.1239 - val_mae: 0.2719
# Epoch 30/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0759 - mae: 0.2149 - val_loss: 0.1204 - val_mae: 0.2681
# Epoch 31/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0740 - mae: 0.2122 - val_loss: 0.1164 - val_mae: 0.2637
# Epoch 32/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0722 - mae: 0.2095 - val_loss: 0.1137 - val_mae: 0.2603
# Epoch 33/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0706 - mae: 0.2070 - val_loss: 0.1110 - val_mae: 0.2568
# Epoch 34/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0690 - mae: 0.2045 - val_loss: 0.1085 - val_mae: 0.2535
# Epoch 35/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0675 - mae: 0.2022 - val_loss: 0.1057 - val_mae: 0.2498
# Epoch 36/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0661 - mae: 0.2000 - val_loss: 0.1043 - val_mae: 0.2478
# Epoch 37/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0650 - mae: 0.1983 - val_loss: 0.1017 - val_mae: 0.2444
# Epoch 38/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0638 - mae: 0.1964 - val_loss: 0.0996 - val_mae: 0.2416
# Epoch 39/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0627 - mae: 0.1947 - val_loss: 0.0978 - val_mae: 0.2392
# Epoch 40/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0617 - mae: 0.1932 - val_loss: 0.0955 - val_mae: 0.2361
# Epoch 41/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0607 - mae: 0.1916 - val_loss: 0.0941 - val_mae: 0.2342
# Epoch 42/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0599 - mae: 0.1903 - val_loss: 0.0932 - val_mae: 0.2330
# Epoch 43/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0591 - mae: 0.1892 - val_loss: 0.0915 - val_mae: 0.2307
# Epoch 44/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0583 - mae: 0.1879 - val_loss: 0.0904 - val_mae: 0.2293
# Epoch 45/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0576 - mae: 0.1868 - val_loss: 0.0898 - val_mae: 0.2286
# Epoch 46/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0570 - mae: 0.1860 - val_loss: 0.0885 - val_mae: 0.2269
# Epoch 47/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0564 - mae: 0.1850 - val_loss: 0.0882 - val_mae: 0.2267
# Epoch 48/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0559 - mae: 0.1842 - val_loss: 0.0879 - val_mae: 0.2267
# Epoch 49/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0554 - mae: 0.1835 - val_loss: 0.0870 - val_mae: 0.2256
# Epoch 50/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0549 - mae: 0.1827 - val_loss: 0.0863 - val_mae: 0.2247
# Epoch 51/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0544 - mae: 0.1819 - val_loss: 0.0871 - val_mae: 0.2266
# Epoch 52/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0541 - mae: 0.1816 - val_loss: 0.0859 - val_mae: 0.2250
# Epoch 53/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0537 - mae: 0.1807 - val_loss: 0.0849 - val_mae: 0.2236
# Epoch 54/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0532 - mae: 0.1799 - val_loss: 0.0846 - val_mae: 0.2236
# Epoch 55/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0529 - mae: 0.1793 - val_loss: 0.0834 - val_mae: 0.2219
# Epoch 56/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0525 - mae: 0.1785 - val_loss: 0.0834 - val_mae: 0.2224
# Epoch 57/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0522 - mae: 0.1781 - val_loss: 0.0831 - val_mae: 0.2222
# Epoch 58/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0519 - mae: 0.1775 - val_loss: 0.0826 - val_mae: 0.2215
# Epoch 59/500
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0501 - mae: 0.1759
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 12
#       2 for i, hidden_nodes in enumerate(hidden_nodes_set):
#       3     model_config = {"n_in": input_dim,
#       4                     "n_out": 1,
#       5                     "epochs": 500,
#    (...)     10                     "train_val_split": '2023-01-01',
#      11                     "test_init": '2024-01-01',}
# ---> 12     models = forecasting_trader.train_models(pairs, model_config, model_type='mlp')
#      13     # save models for this configuration
#      14     with open(f'{current_path}/models/mlp/models_n_in-'+str(input_dim)+'_hidden_nodes-'+hidden_nodes_names[i]+'.pkl', 'wb') as f:
#
# File /mnt/d/GitHub/WQU-Capstone/notebooks/classes/class_ForecastingTrader.py:569, in ForecastingTrader.train_models(self, pairs, model_config, model_type)
#     566 # train model and get predictions
#     567 if model_type == 'mlp':
#     568     model, history, score, predictions_train, predictions_val, predictions_test = \
# --> 569                                                   self.apply_MLP(X=train_data[0],
#     570                                                                 y=train_data[1],
#     571                                                                 validation_data=validation_data,
#     572                                                                 test_data=test_data,
#     573                                                                 n_in=model_config['n_in'],
#     574                                                                 hidden_nodes=model_config['hidden_nodes'],
#     575                                                                 epochs=model_config['epochs'],
#     576                                                                 optimizer=model_config['optimizer'],
#     577                                                                 loss_fct=model_config['loss_fct'],
#     578                                                                 batch_size=model_config['batch_size'])
#     580 elif model_type == 'rnn':
#     581     model, history, score, predictions_train, predictions_val, predictions_test = \
#     582                                                   self.apply_RNN(X=train_data[0],
#     583                                                                  y=train_data[1],
#    (...)    589                                                                  loss_fct=model_config['loss_fct'],
#     590                                                                  batch_size=model_config['batch_size'])
#
# File /mnt/d/GitHub/WQU-Capstone/notebooks/classes/class_ForecastingTrader.py:693, in ForecastingTrader.apply_MLP(self, X, y, validation_data, test_data, n_in, hidden_nodes, epochs, optimizer, loss_fct, batch_size)
#     688 #print(keras2ascii(model))
#     689
#     690 # simple early stopping
#     691 es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
# --> 693 history = model.fit(X, y, epochs=epochs, verbose=1, validation_data=validation_data,
#     694                     shuffle=False, batch_size=batch_size, callbacks=[es])
#     696 # scores
#     697 if len(history.history['loss']) < 500:
#
# File ~/miniconda3/envs/tf/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:395, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     384 if getattr(self, "_eval_epoch_iterator", None) is None:
#     385     self._eval_epoch_iterator = TFEpochIterator(
#     386         x=val_x,
#     387         y=val_y,
#    (...)    393         shuffle=False,
#     394     )
# --> 395 val_logs = self.evaluate(
#     396     x=val_x,
#     397     y=val_y,
#     398     sample_weight=val_sample_weight,
#     399     batch_size=validation_batch_size or batch_size,
#     400     steps=validation_steps,
#     401     callbacks=callbacks,
#     402     return_dict=True,
#     403     _use_cached_eval_dataset=True,
#     404 )
#     405 val_logs = {
#     406     "val_" + name: val for name, val in val_logs.items()
#     407 }
#     408 epoch_logs.update(val_logs)
#
# File ~/miniconda3/envs/tf/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:481, in TensorFlowTrainer.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, return_dict, **kwargs)
#     479 self.reset_metrics()
#     480 with epoch_iterator.catch_stop_iteration():
# --> 481     for step, iterator in epoch_iterator:
#     482         callbacks.on_test_batch_begin(step)
#     483         logs = self.test_function(iterator)
#
# File ~/miniconda3/envs/tf/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:734, in TFEpochIterator.__next__(self)
#     733 def __next__(self):
# --> 734     return next(self._epoch_iterator)
#
# File ~/miniconda3/envs/tf/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:102, in EpochIterator._enumerate_iterator(self)
#     100 if steps_per_epoch > 0:
#     101     if self._current_iterator is None or self.steps_per_epoch is None:
# --> 102         self._current_iterator = iter(self._get_iterator())
#     103         self._steps_seen = 0
#     104     for step in range(0, steps_per_epoch, self.steps_per_execution):
#
# File ~/miniconda3/envs/tf/lib/python3.12/site-packages/tensorflow/python/data/ops/dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499 if context.executing_eagerly() or ops.inside_function():
#     500   with ops.colocate_with(self._variant_tensor):
# --> 501     return iterator_ops.OwnedIterator(self)
#     502 else:
#     503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# File ~/miniconda3/envs/tf/lib/python3.12/site-packages/tensorflow/python/data/ops/iterator_ops.py:709, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     705   if (components is not None or element_spec is not None):
#     706     raise ValueError(
#     707         "When `dataset` is provided, `element_spec` and `components` must "
#     708         "not be specified.")
# --> 709   self._create_iterator(dataset)
#     711 self._get_next_call_count = 0
#
# File ~/miniconda3/envs/tf/lib/python3.12/site-packages/tensorflow/python/data/ops/iterator_ops.py:748, in OwnedIterator._create_iterator(self, dataset)
#     745   assert len(fulltype.args[0].args[0].args) == len(
#     746       self._flat_output_types)
#     747   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 748 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~/miniconda3/envs/tf/lib/python3.12/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3478, in make_iterator(dataset, iterator, name)
#    3476 if tld.is_eager:
#    3477   try:
# -> 3478     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3479       _ctx, "MakeIterator", name, dataset, iterator)
#    3480     return _result
#    3481   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
for input_dim in n_in_set:
    for i, hidden_nodes in enumerate(hidden_nodes_set):
        print('input_dim:', input_dim)

        print(i,' hidden_nodes:', hidden_nodes)
# Out:
# input_dim: 24
# 0  hidden_nodes: [30]
# input_dim: 24
# 1  hidden_nodes: [50]
