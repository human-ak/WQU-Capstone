# %% [markdown]
# # Setup

# %%
import os
#os.chdir('/mnt/f/etfs/Cluster2')

# Printing current/ working directories
current_dir = os.getcwd()
print("Notebooks directory:", current_dir)

# Obtenir le répertoire parent
parent_dir = os.path.dirname(current_dir)
print("Local working directory:", parent_dir)

data_dir = parent_dir+"/data/"
print("Data directory:", data_dir)
# Out:
# Notebooks directory: /Users/omar/Documents/WQU-Capstone/notebooks
# Local working directory: /Users/omar/Documents/WQU-Capstone
# Data directory: /Users/omar/Documents/WQU-Capstone/data/

# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt

# %% [markdown]
# ## Import data

# %%
pkl_data = "etf_data_with_indicators.pkl"
index_dict = pd.read_pickle(pkl_data)
index_dict
# Out:
# {'ARKK':                             adjClose    adjHigh     adjLow    adjOpen  \
#  date
#  2018-01-02 00:00:00+00:00  36.133634  36.143000  34.885160  34.972263
#  2018-01-03 00:00:00+00:00  36.283489  36.576641  36.274123  36.480173
#  2018-01-04 00:00:00+00:00  36.405245  36.704954  36.039975  36.620661
#  2018-01-05 00:00:00+00:00  36.995297  36.995297  36.592563  36.770515
#  2018-01-08 00:00:00+00:00  36.742418  36.742418  35.890121  36.536368
#  ...                              ...        ...        ...        ...
#  2024-12-24 00:00:00+00:00  60.960000  60.990000  59.440000  59.630000
#  2024-12-26 00:00:00+00:00  60.960000  61.135000  60.040000  60.720000
#  2024-12-27 00:00:00+00:00  59.270000  60.600000  58.440000  60.540000
#  2024-12-30 00:00:00+00:00  57.610000  58.230000  56.900000  58.010000
#  2024-12-31 00:00:00+00:00  56.770000  58.170000  56.475000  58.040000
#
#                             adjVolume        RSI        ADX      MACD  \
#  date
#  2018-01-02 00:00:00+00:00     420381        NaN        NaN       NaN
#  2018-01-03 00:00:00+00:00     667492        NaN        NaN       NaN
#  2018-01-04 00:00:00+00:00     358595        NaN        NaN       NaN
#  2018-01-05 00:00:00+00:00     361640        NaN        NaN       NaN
#  2018-01-08 00:00:00+00:00     421467        NaN        NaN       NaN
#  ...                              ...        ...        ...       ...
#  2024-12-24 00:00:00+00:00    4801695  58.035755  33.491656  1.472630
#  2024-12-26 00:00:00+00:00    6888985  58.035755  32.164813  1.433355
#  2024-12-27 00:00:00+00:00    9592628  51.908635  29.892408  1.251435
#  2024-12-30 00:00:00+00:00    8456884  46.693957  28.564485  0.962222
#  2024-12-31 00:00:00+00:00    8702097  44.270379  27.542766  0.657657
#
#                             MACD_signal      SMA_2  ...     SMA_55    ATR_13  \
#  date                                               ...
#  2018-01-02 00:00:00+00:00          NaN        NaN  ...        NaN       NaN
#  2018-01-03 00:00:00+00:00          NaN  36.208562  ...        NaN       NaN
#  2018-01-04 00:00:00+00:00          NaN  36.344367  ...        NaN       NaN
#  2018-01-05 00:00:00+00:00          NaN  36.700271  ...        NaN       NaN
#  2018-01-08 00:00:00+00:00          NaN  36.868857  ...        NaN       NaN
#  ...                                ...        ...  ...        ...       ...
#  2024-12-24 00:00:00+00:00     1.990735  60.100000  ...  53.898909  1.993132
#  2024-12-26 00:00:00+00:00     1.879259  60.960000  ...  54.159273  1.924044
#  2024-12-27 00:00:00+00:00     1.753694  60.115000  ...  54.388727  1.969887
#  2024-12-30 00:00:00+00:00     1.595400  58.440000  ...  54.596727  2.000665
#  2024-12-31 00:00:00+00:00     1.407851  57.190000  ...  54.780909  1.977152
#
#                               ATR_55  VolRatio_5_21  Return_2d  Return_5d  \
#  date
#  2018-01-02 00:00:00+00:00       NaN            NaN        NaN        NaN
#  2018-01-03 00:00:00+00:00       NaN            NaN        NaN        NaN
#  2018-01-04 00:00:00+00:00       NaN            NaN   0.007517        NaN
#  2018-01-05 00:00:00+00:00       NaN            NaN   0.019618        NaN
#  2018-01-08 00:00:00+00:00       NaN            NaN   0.009262        NaN
#  ...                             ...            ...        ...        ...
#  2024-12-24 00:00:00+00:00  1.607671       1.187112   0.026263  -0.032074
#  2024-12-26 00:00:00+00:00  1.598350       1.088897   0.029034   0.040984
#  2024-12-27 00:00:00+00:00  1.615107       1.127312  -0.027723   0.018910
#  2024-12-30 00:00:00+00:00  1.628833       1.142369  -0.054954  -0.030135
#  2024-12-31 00:00:00+00:00  1.630036       1.099464  -0.042180  -0.041695
#
#                             Return_13d  Return_21d  Return_55d          OBV
#  date
#  2018-01-02 00:00:00+00:00         NaN         NaN         Na
#  2018-01-08 00:00:00+00:00         NaN         NaN         NaN   1670793.0
#  ...                               ...         ...         ...         ...
#  2024-12-24 00:00:00+00:00   -0.015234    0.008244    0.009406  26813191.0
#  2024-12-26 00:00:00+00:00   -0.022119   -0.002898    0.013399  26905727.0
#  2024-12-27 00:00:00+00:00   -0.027469   -0.007337   -0.001314  26772989.0
#  2024-12-30 00:00:00+00:00   -0.026440   -0.017695   -0.012697  26711312.0
#  2024-12-31 00:00:00+00:00   -0.039834   -0.028305   -0.021638  26582049.0
#
#  [1761 rows x 23 columns]}

# %%
len(index_dict)
# Out:
# 75

# %%
index_keys = list(index_dict.keys())
for index in index_keys:
  if (index_dict[index].shape[0] == 0):
    del(index_dict[index])

# %%
for index in index_dict:
  print(index_dict[index].shape)
# Out:
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1760, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)
# (1761, 23)

# %%
indices = list(index_dict.keys())
indices
# Out:
# ['ARKK',
#  'ARKQ',
#  'ARKW',
#  'CIBR',
#  'CQQQ',
#  'CWEB',
#  'DTEC',
#  'FDN',
#  'FTC',
#  'FTEC',
#  'FTXL',
#  'FXI',
#  'FXL',
#  'FXP',
#  'FYC',
#  'GAMR',
#  'HACK',
#  'IDLV',
#  'IDMO',
#  'IDX',
#  'IEFA',
#  'IGM',
#  'IGV',
#  'IPAY',
#  'ISMD',
#  'ISRA',
#  'ITEQ',
#  'IXN',
#  'IYW',
#  'KEMQ',
#  'KGRN',
#  'KWEB',
#  'LRGE',
#  'MTUM',
#  'NULG',
#  'NUMG',
#  'NXTG',
#  'ONEQ',
#  'PIN',
#  'PIZ',
#  'PNQI',
#  'PRNT',
#  'PSCT',
#  'PSI',
#  'PTF',
#  'QQEW',
#  'QQQ',
#  'QQQE',
#  'QQXT',
#  'QTEC',
#  'QYLD',
#  'REW',
#  'ROM',
#  'SKYY',
#  'SMH',
#  'SNSR',
#  'SOXL',
#  'SOXS',
#  'SOXX',
#  'SUSA',
#  'TDIV',
#  'TECL',
#  'TECS',
#  'TLTD',
#  'TLTE',
#  'TQQQ',
#  'USD',
#  'VGT',
#  'VV',
#  'XITK',
#  'XLK',
#  'XNTK',
#  'XSD',
#  'XSW',
#  'XT']

# %%
reformed_dict = {}
for outerKey, innerDict in index_dict.items():
    for innerKey, values in innerDict.items():
        reformed_dict[(outerKey,
                       innerKey)] = values

# %%
data = pd.DataFrame(reformed_dict)
data.shape
# Out:
# (1761, 1725)

# %%
data.isna()
# Out:
#                               ARKK                                          \
#                           adjClose adjHigh adjLow adjOpen adjVolume    RSI
# date
# 2018-01-02 00:00:00+00:00    False   False  False   False     False   True
# 2018-01-03 00:00:00+00:00    False   False  False   False     False   True
# 2018-01-04 00:00:00+00:00    False   False  False   False     False   True
# 2018-01-05 00:00:00+00:00    False   False  False   False     False   True
# 2018-01-08 00:00:00+00:00    False   False  False   False     False   True
# ...                            ...     ...    ...     ...       ...    ...
# 2024-12-24 00:00:00+00:00    False   False  False   False     False  False
# 2024-12-26 00:00:00+00:00    False   False  False   False     False  False
# 2024-12-27 00:00:00+00:00    False   False  False   False     False  False
# 2024-12-30 00:00:00+00:00    False   False  False   False     False  False
# 2024-12-31 00:00:00+00:00    False   False  False   False     False  False
#
#                                                             ...     XT         \
#                              ADX   MACD MACD_signal  SMA_2  ... SMA_55 ATR_13
# date                                                        ...
# 2018-01-02 00:00:00+00:00   True   True        True   True  ...   True   True
# 2018-01-03 00:00:00+00:00   True   True        True  False  ...   True   True
# 2018-01-04 00:00:00+00:00   True   True        True  False  ...   True   True
# 2018-01-05 00:00:00+00:00   True   True        True  False  ...   True   True
# 2018-01-08 00:00:00+00:00   True   True        True  False  ...   True   True
# ...                          ...    ...         ...    ...  ...    ...    ...
# 2024-12-24 00:00:00+00:00  False  False       False  False  ...  False  False
# 2024-12-26 00:00:00+00:00  False  False       False  False  ...  False  False
# 2024-12-27 00:00:00+00:00  False  False       False  False  ...  False  False
# 2024-12-30 00:00:00+00:00  False  False       False  False  ...  False  False
# 2024-12-31 00:00:00+00:00  False  False       False  False  ...  False  False
#
#                                                                                \
#                           ATR_55 VolRatio_5_21 Return_2d Return_5d Return_13d
# date
# 2018-01-02 00:00:00+00:00   True          True      True      True       True
# 2018-01-03 00:00:00+00:00   True          True      True      True       True
# 2018-01-04 00:00:00+00:00   True          True     False      True       True
# 2018-01-05 00:00:00+00:00   True          True     False      True       True
# 2018-01-08 00:00:00+00:00   True          True     False      True       True
# ...                          ...           ...       ...       ...        ...
# 2024-12-24 00:00:00+00:00  False         False     False     False      False
# 2024-12-26 00:00:00+00:00  False         False     False     False      False
# 2024-12-27 00:00:00+00:00  False         False     False     False      False
# 2024-12-30 00:00:00+00:00  False         False     False     False      False
# 2024-12-31 00:00:00+00:00  False         False     False     False      False
#
#
#                           Return_21d Return_55d    OBV
# date
# 2018-01-02 00:00:00+00:00       True       True  False
# 2018-01-03 00:00:00+00:00       True       True  False
# 2018-01-04 00:00:00+00:00       True       True  False
# 2018-01-05 00:00:00+00:00       True       True  False
# 2018-01-08 00:00:00+00:00       True       True  False
# ...                              ...        ...    ...
# 2024-12-24 00:00:00+00:00      False      False  False
# 2024-12-26 00:00:00+00:00      False      False  False
# 2024-12-27 00:00:00+00:00      False      False  False
# 2024-12-30 00:00:00+00:00      False      False  False
# 2024-12-31 00:00:00+00:00      False      False  False
#
# [1761 rows x 1725 columns]

# %%
data = data.dropna(axis=0, how='any')
data.shape
# Out:
# (1705, 2250)

# %% [markdown]
# ## tf start

# %%
import tensorflow as tf
from keras.layers import Conv2D, Conv2DTranspose, Dense, Flatten, Reshape
from keras.models import Sequential, Model
from tensorflow.keras.utils import plot_model #from keras.utils.vis_utils import plot_model
import numpy as np
import pandas as pd

# %%
import numpy as np
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score

nmi = normalized_mutual_info_score
ari = adjusted_rand_score

def acc(y_true, y_pred):
    """
    Calculate clustering accuracy. Require scikit-learn installed
    # Arguments
        y: true labels, numpy.array with shape `(n_samples,)`
        y_pred: predicted labels, numpy.array with shape `(n_samples,)`
    # Return
        accuracy, in [0,1]
    """
    y_true = y_true.astype(np.int64)
    assert y_pred.size == y_true.size
    D = max(y_pred.max(), y_true.max()) + 1
    w = np.zeros((D, D), dtype=np.int64)
    for i in range(y_pred.size):
        w[y_pred[i], y_true[i]] += 1
    from sklearn.utils.linear_assignment_ import linear_assignment
    ind = linear_assignment(w.max() - w)
    return sum([w[i, j] for i, j in ind]) * 1.0 / y_pred.size

# %%
n_clusters = 5 #10
args = {
        'n_clusters' : n_clusters,
        'batch_size' : 32,
        'epochs' : 1000,
        'save_dir' : 'results/temp'
}
print(args)
# Out:
# {'n_clusters': 5, 'batch_size': 32, 'epochs': 1000, 'save_dir': 'results/temp'}

# %%
import os
if not os.path.exists(args['save_dir']):
  os.makedirs(args['save_dir'])

# %%
data.shape
# Out:
# (1705, 2250)

# %%
print(f'No. of indices = {len(indices)}')
print(indices)
# Out:
# No. of indices = 75
# ['ARKK', 'ARKQ', 'ARKW', 'CIBR', 'CQQQ', 'CWEB', 'DTEC', 'FDN', 'FTC', 'FTEC', 'FTXL', 'FXI', 'FXL', 'FXP', 'FYC', 'GAMR', 'HACK', 'IDLV', 'IDMO', 'IDX', 'IEFA', 'IGM', 'IGV', 'IPAY', 'ISMD', 'ISRA', 'ITEQ', 'IXN', 'IYW', 'KEMQ', 'KGRN', 'KWEB', 'LRGE', 'MTUM', 'NULG', 'NUMG', 'NXTG', 'ONEQ', 'PIN', 'PIZ', 'PNQI', 'PRNT', 'PSCT', 'PSI', 'PTF', 'QQEW', 'QQQ', 'QQQE', 'QQXT', 'QTEC', 'QYLD', 'REW', 'ROM', 'SKYY', 'SMH', 'SNSR', 'SOXL', 'SOXS', 'SOXX', 'SUSA', 'TDIV', 'TECL', 'TECS', 'TLTD', 'TLTE', 'TQQQ', 'USD', 'VGT', 'VV', 'XITK', 'XLK', 'XNTK', 'XSD', 'XSW', 'XT']

# %%
n_timesteps = data.shape[0]
n_features = data[indices[0]].shape[1]
n_indices = int(data.shape[1]/data[indices[0]].shape[1])
print(f'n_timesteps : {n_timesteps}, n_features : {n_features}, n_indices : {n_indices}')
# Out:
# n_timesteps : 1705, n_features : 30, n_indices : 75

# %%
from sklearn.preprocessing import StandardScaler

# Normaliser les données par colonne pour chaque ETF
normalized_data = data.copy()
for etf in indices:
    # Sélectionner toutes les colonnes pour cet ETF
    etf_cols = [(etf, col) for col in data.columns.get_level_values(1).unique()]
    # Standardiser chaque colonne de cet ETF
    scaler = StandardScaler()
    normalized_data[etf_cols] = scaler.fit_transform(data[etf_cols].values)

# Puis utiliser normalized_data au lieu de data
x = normalized_data.values
x = x.reshape(-1, n_timesteps, n_features, 1).astype('float32')

# %%
x.shape
# Out:
# (75, 1705, 30, 1)

# %%
x
# Out:
# array([[[[-0.6686653 ],
#          [-0.65630406],
#          [-0.64454794],
#          ...,
#          [-0.0173398 ],
#          [ 0.22892661],
#          [ 0.8372221 ]],
#
#         [[-1.0759691 ],
#          [-1.0532057 ],
#          [-1.0577109 ],
#          ...,
#          [-0.3216956 ],
#          [-0.08046287],
#          [-1.2615008 ]],
#
#         [[-0.746194  ],
#          [-0.7354184 ],
#          [-0.7245919 ],
#          ...,
#          [ 0.01115327],
#          [ 0.27558553],
#          [-0.45638967]],
#
#         ...,
#
#         [[ 0.1527276 ],
#          [ 0.23763253],
#          [ 0.15823787],
#          ...,
#          [-0.10398113],
#          [-0.33772594],
#          [-0.5461283 ]],
#
#         [[-1.3855577 ],
#          [-1.3559606 ],
#          [-1.3732207 ],
#          ...,
#          [ 0.14441079],
#          [-0.13192792],
#          [-1.6037854 ]],
#
#         [[-1.4218776 ],
#          [-1.3979391 ],
#          [-1.4198095 ],
#          ...,
#          [-0.8130425 ],
#          [-0.6260978 ],
#          [-0.1199663 ]]],
#
#
#        [[[-1.3600968 ],
#          [-1.3332694 ],
#          [-1.3509479 ],
#          ...,
#          [-0.48785982],
#          [-0.645783  ],
#          [-1.5840311 ]],
#
#         [[ 0.13071398],
#          [ 0.18176796],
#          [ 0.13682866],
#          ...,
#          [-0.8578002 ],
#          [-0.67631394],
#          [-0.54005224]],
#
#         [[-0.33263302],
#          [-0.34436372],
#          [-0.37531757],
#          ...,
#          [-0.11836029],
#          [-0.28444314],
#          [ 0.7243233 ]],
#
#         ...,
#
#         [[-1.2955166 ],
#          [-1.3099641 ],
#          [-1.2808015 ],
#          ...,
#          [ 0.57556766],
#          [-0.34338692],
#          [-1.5414623 ]],
#
#         [[-1.2878963 ],
#          [-1.2761205 ],
#          [-1.2786152 ],
#          ...,
#          [ 0.24567366],
#          [-0.62597764],
#          [-2.3966    ]],
#
#         [[-1.3311863 ],
#          [-1.2662432 ],
#          [-1.314933  ],
#          ...,
#          [ 0.31141648],
#          [-0.43107128],
#          [ 0.06751261]]],
#
#
#        [[[-1.1801043 ],
#          [-1.2059473 ],
#          [-1.1521006 ],
#          ...,
#          [ 0.2536271 ],
#          [-0.30285475],
#          [-1.1528618 ]],
#
#         [[-1.122741  ],
#          [-1.136584  ],
#          [-1.1010729 ],
#          ...,
#          [-0.09919295],
#          [-1.2906519 ],
#          [-1.7361481 ]],
#
#         [[ 0.64958996],
#          [ 0.6439927 ],
#          [ 0.65431416],
#          ...,
#          [ 0.333226  ],
#          [-0.13620952],
#          [ 0.40207717]],
#
#         ...,
#
#         [[-1.4872719 ],
#          [-1.493702  ],
#          [-1.4642671 ],
#          ...,
#          [-0.40677804],
#          [-0.27912736],
#          [-2.0442464 ]],
#
#         [[ 1.6504908 ],
#          [ 1.6144267 ],
#          [ 1.659369  ],
#          ...,
#          [ 0.3016868 ],
#          [ 5.817233  ],
#          [-2.2685468 ]],
#
#         [[-0.7508082 ],
#          [-0.757307  ],
#          [-0.7287125 ],
#          ...,
#          [ 0.13477418],
#          [ 0.59138405],
#          [-1.1344547 ]]],
#
#
#        ...,
#
#
#        [[[ 2.280571  ],
#          [ 2.2474887 ],
#          [ 2.2743034 ],
#          ...,
#          [ 0.3976496 ],
#          [-0.06427506],
#          [ 2.0257096 ]],
#
#         [[-0.35512188],
#          [-0.3699953 ],
#          [-0.36681417],
#          ...,
#          [-0.2925723 ],
#          [-0.81648123],
#          [ 2.171157  ]],
#
#         [[-1.0458685 ],
#          [-1.0346731 ],
#          [-1.0469004 ],
#          ...,
#          [-0.20049849],
#          [-0.24214041],
#          [-0.9728754 ]],
#
#         ...,
#
#         [[-0.7434078 ],
#          [-0.74258083],
#          [-0.7410595 ],
#          ...,
#          [ 0.15660435],
#          [ 0.5556981 ],
#          [ 0.13418737]],
#
#         [[ 1.3909883 ],
#          [ 1.4302868 ],
#          [ 1.4012724 ],
#          ...,
#          [-1.2767345 ],
#          [-0.29463217],
#          [ 1.0664247 ]],
#
#         [[ 1.3291829 ],
#          [ 1.3696214 ],
#          [ 1.3510197 ],
#          ...,
#          [-0.78870124],
#          [ 0.7561631 ],
#          [-0.28285673]]],
#
#
#        [[[-1.4164844 ],
#          [-1.4158399 ],
#          [-1.4094309 ],
#          ...,
#          [ 0.02917892],
#          [ 0.6324803 ],
#          [ 2.505812  ]],
#
#         [[-0.76220405],
#          [-0.75935256],
#          [-0.7411533 ],
#          ...,
#          [-0.35497445],
#          [ 0.42910495],
#          [-0.22420679]],
#
#         [[-1.4030004 ],
#          [-1.3918232 ],
#          [-1.3912474 ],
#          ...,
#          [-0.23939438],
#          [ 0.2073827 ],
#          [-1.171886  ]],
#
#         ...,
#
#         [[-0.35910353],
#          [-0.3810826 ],
#          [-0.3398994 ],
#          ...,
#          [-0.21004087],
#          [-0.606875  ],
#          [-0.29034725]],
#
#         [[ 1.910987  ],
#          [ 1.8898374 ],
#          [ 1.9226594 ],
#          ...,
#          [ 0.07790593],
#          [-0.07647026],
#          [ 0.9965851 ]],
#
#         [[-1.2144748 ],
#          [-1.2427149 ],
#          [-1.191638  ],
#          ...,
#          [-0.81720716],
#          [-0.92756444],
#          [-2.579282  ]]],
#
#
#        [[[ 0.98170155],
#          [ 0.9700869 ],
#          [ 0.99309254],
#          ...,
#          [-0.57794   ],
#          [-0.50006324],
#          [-0.3251801 ]],
#
#         [[-1.6905504 ],
#          [-1.6923188 ],
#          [-1.6892153 ],
#          ...,
#          [ 0.03047089],
#          [ 0.48482606],
#          [ 3.1492913 ]],
#
#         [[-1.6624438 ],
#          [-1.6600068 ],
#          [-1.6574374 ],
#          ...,
#          [ 0.91884   ],
#          [ 1.0145785 ],
#          [ 4.3074393 ]],
#
#         ...,
#
#         [[ 1.5168021 ],
#          [ 1.5428514 ],
#          [ 1.555342  ],
#          ...,
#          [-0.18818988],
#          [-0.24584825],
#          [ 0.40721402]],
#
#         [[ 2.053488  ],
#          [ 2.0898693 ],
#          [ 2.0867062 ],
#          ...,
#          [-0.6080666 ],
#          [ 0.93330544],
#          [ 0.7032447 ]],
#
#         [[ 0.9889483 ],
#          [ 1.0059515 ],
#          [ 1.0146575 ],
#          ...,
#          [-0.6899138 ],
#          [-0.5214039 ],
#          [ 0.56883335]]]], shape=(75, 1705, 30, 1), dtype=float32)

# %%
print(data.columns.get_level_values(1).unique())
# Out:
# Index(['close', 'high', 'low', 'open', 'volume', 'adjClose', 'adjHigh',
#        'adjLow', 'adjOpen', 'adjVolume', 'divCash', 'splitFactor', 'RSI',
#        'ADX', 'MACD', 'MACD_signal', 'SMA_2', 'SMA_5', 'SMA_13', 'SMA_21',
#        'SMA_55', 'ATR_13', 'ATR_55', 'VolRatio_5_21', 'Return_2d', 'Return_5d',
# 2018-03-23 00:00:00+00:00 -0.043467 -0.052812  -0.039882  -0.022882
# 2018-03-26 00:00:00+00:00  0.002426 -0.017917  -0.018179  -0.012114
# 2018-03-27 00:00:00+00:00  0.007527 -0.036267  -0.039341  -0.039085
# 2018-03-28 00:00:00+00:00 -0.021181 -0.040000  -0.056109  -0.032258
# ...                             ...       ...        ...        ...
# 2024-12-24 00:00:00+00:00  0.011589 -0.011007  -0.018789   0.004604
# 2024-12-26 00:00:00+00:00  0.006418  0.023770  -0.025649  -0.006498
# 2024-12-27 00:00:00+00:00 -0.006874  0.017779  -0.030981  -0.010921
# 2024-12-30 00:00:00+00:00 -0.020275 -0.007947  -0.030107  -0.021395
# 2024-12-31 00:00:00+00:00 -0.016809 -0.018266  -0.043450  -0.031965
#
#
#                           Return_55d         OBV
# date
# 2018-03-22 00:00:00+00:00   0.021721  13031681.0
# 2018-03-23 00:00:00+00:00  -0.009116  12877966.0
# 2018-03-26 00:00:00+00:00   0.012080  13041351.0
# 2018-03-27 00:00:00+00:00  -0.013646  12785688.0
# 2018-03-28 00:00:00+00:00  -0.018539  12280221.0
# ...                              ...         ...
# 2024-12-24 00:00:00+00:00   0.005761  26692243.0
# 2024-12-26 00:00:00+00:00   0.009741  26784779.0
# 2024-12-27 00:00:00+00:00  -0.004920  26652041.0
# 2024-12-30 00:00:00+00:00  -0.016415  26590364.0
# 2024-12-31 00:00:00+00:00  -0.025323  26461101.0
#
# [1705 rows x 2250 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1705 entries, 2018-03-22 00:00:00+00:00 to 2024-12-31 00:00:00+00:00
# Columns: 2250 entries, ('ARKK', 'close') to ('XT', 'OBV')
# dtypes: float64(2102), int64(148)
# memory usage: 29.3 MB

# %%
#drop missing values
data = data.dropna(axis=0, how='any')

# %% [markdown]
# ## tf model

# %%
from keras.layers import BatchNormalization

model = Sequential()
input_shape = x.shape[1:]
filters = [32, 64, 128, n_clusters]

model.add(BatchNormalization(input_shape=input_shape))

#encoding layer
if input_shape[0] % 8 == 0:
    pad3 = 'same'
else:
    pad3 = 'valid'
model.add(Conv2D(filters[0], 5, strides=1, padding='same', activation='relu', name='conv1', input_shape=input_shape))
model.add(BatchNormalization())
model.add(Conv2D(filters[1], 5, strides=1, padding='same', activation='relu', name='conv2'))
model.add(BatchNormalization())
model.add(Conv2D(filters[2], 3, strides=1, padding=pad3, activation='relu', name='conv3'))
model.add(BatchNormalization())
model.add(Flatten(name = 'flatten'))
model.add(Dense(units=filters[3], name='embedding'))

prev_layer_output = model.get_layer(index=model.layers.index(model.get_layer('flatten'))-1).output
flattened_size = np.prod(prev_layer_output.shape[1:])
model.add(Dense(units=int(flattened_size), activation='relu')) #model.add(Dense(units = model.get_layer(name='flatten').output_shape[-1], activation = 'relu'))

model.summary()
# Out:
# /Users/omar/Documents/WQU-Capstone/.venv/lib/python3.11/site-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /Users/omar/Documents/WQU-Capstone/.venv/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ batch_normalization             │ (None, 1705, 30, 1)    │             4 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1 (Conv2D)                  │ (None, 1705, 30, 32)   │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 1705, 30, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv2D)                  │ (None, 1705, 30, 64)   │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 1705, 30, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3 (Conv2D)                  │ (None, 1703, 28, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 1703, 28, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6103552)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding (Dense)               │ (None, 5)              │    30,517,765 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 6103552)        │    36,621,312 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 67,265,929 (256.60 MB)
#  Trainable params: 67,265,479 (256.60 MB)
#  Non-trainable params: 450 (1.76 KB)

# %%
#decoding layers

model.add(Reshape((input_shape[0]-2, input_shape[1] - 2, filters[2])))

model.add(Conv2DTranspose(filters[1], 3, strides=1, padding=pad3, activation='relu', name='deconv3'))

model.add(Conv2DTranspose(filters[0], 5, strides=1, padding='same', activation='relu', name='deconv2'))

model.add(Conv2DTranspose(input_shape[2], 5, strides=1, padding='same', name='deconv1'))
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ batch_normalization             │ (None, 1705, 30, 1)    │             4 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1 (Conv2D)                  │ (None, 1705, 30, 32)   │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 1705, 30, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv2D)                  │ (None, 1705, 30, 64)   │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 1705, 30, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3 (Conv2D)                  │ (None, 1703, 28, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 1703, 28, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6103552)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding (Dense)               │ (None, 5)              │    30,517,765 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 6103552)        │    36,621,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 1703, 28, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv3 (Conv2DTranspose)       │ (None, 1705, 30, 64)   │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv2 (Conv2DTranspose)       │ (None, 1705, 30, 32)   │        51,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv1 (Conv2DTranspose)       │ (None, 1705, 30, 1)    │           801 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 67,391,754 (257.08 MB)
#  Trainable params: 67,391,304 (257.08 MB)
#  Non-trainable params: 450 (1.76 KB)

# %%
# define the model
plot_model(model, to_file=args['save_dir'] + '/%s-pretrain-model.png' % 'data', show_shapes=True)
model.summary()
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ batch_normalization             │ (None, 1705, 30, 1)    │             4 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1 (Conv2D)                  │ (None, 1705, 30, 32)   │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 1705, 30, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv2D)                  │ (None, 1705, 30, 64)   │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 1705, 30, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3 (Conv2D)                  │ (None, 1703, 28, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 1703, 28, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6103552)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding (Dense)               │ (None, 5)              │    30,517,765 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 6103552)        │    36,621,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 1703, 28, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv3 (Conv2DTranspose)       │ (None, 1705, 30, 64)   │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv2 (Conv2DTranspose)       │ (None, 1705, 30, 32)   │        51,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ deconv1 (Conv2DTranspose)       │ (None, 1705, 30, 1)    │           801 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 67,391,754 (257.08 MB)
#  Trainable params: 67,391,304 (257.08 MB)
#  Non-trainable params: 450 (1.76 KB)

# %%
# compile the model and callbacks
optimizer = 'adam'
model.compile(optimizer=optimizer, loss='mse')
from keras.callbacks import CSVLogger
csv_logger = CSVLogger(args['save_dir'] + '/%s-pretrain-log.csv' % 'data')

# %% [markdown]
# ## Trainer

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'loss', patience = 5)
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath = 'best_model.keras', monitor = 'loss', save_best_only = True)
#args['batch_size'] = 8
#args['epochs'] = 1000
#args['save_dir'] = 'results/temp'

# begin training
from time import time
t0 = time()

model.fit(x, x, 
    batch_size=8, #args['batch_size'], 
    epochs=args['epochs'], 
    verbose = 1, 
    callbacks=[early_stopping, model_checkpoint, csv_logger]
    ) 
print('Training time: ', time() - t0)
model.save(args['save_dir'] + '/%s-pretrain-model-%d.keras' % ('data', args['epochs']))
# Out:
# Epoch 1/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1.1124
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - loss: 1.1104
# Epoch 2/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - loss: 1.0166
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 50s 5s/step - loss: 1.0139
# Epoch 3/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.9301
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 124s 12s/step - loss: 0.9342
# Epoch 4/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - loss: 0.9852
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 105s 11s/step - loss: 0.9842
# Epoch 5/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 88s 8s/step - loss: 0.9913
# Epoch 6/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 84s 8s/step - loss: 0.9821
# Epoch 7/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - loss: 0.9704
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 85s 8s/step - loss: 0.9708
# Epoch 8/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - loss: 0.9820
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 102s 10s/step - loss: 0.9814
# Epoch 9/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - loss: 1.0296
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 98s 10s/step - loss: 1.0246
# Epoch 10/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 91s 9s/step - loss: 0.9494
# Epoch 11/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 85s 8s/step - loss: 0.9722
# Epoch 12/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - loss: 0.9555
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 88s 9s/step - loss: 0.9573
# Epoch 13/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - loss: 1.0503
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 89s 9s/step - loss: 1.0435
# Epoch 14/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - loss: 1.0154
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 97s 10s/step - loss: 1.0118
# Epoch 15/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 100s 10s/step - loss: 0.9836
# Epoch 16/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 89s 9s/step - loss: 0.9781
# Epoch 17/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 74s 7s/step - loss: 0.9563
# Epoch 18/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 45s 4s/step - loss: 0.9919
# Epoch 19/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 936s 103s/step - loss: 0.9292
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Training time:  2460.749974012375

# %%
import matplotlib.pyplot as plt
training_loss = model.history.history['loss']
epoch_count = range(1, len(training_loss) + 1)
plt.figure(figsize = (25,5))
plt.plot(epoch_count[2:], training_loss[2:], "r--")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Training Loss"])
plt.show()

# %%
model
# Out:
# <Sequential name=sequential_1, built=True>

# %%
features = model.predict(x)
features
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step
# array([[[[ 0.1967948 ],
#          [ 0.10978965],
#          [ 0.14350957],
#          ...,
#          [ 0.1445196 ],
#          [ 0.07842423],
#          [-0.01061151]],
#
#         [[-0.09554969],
#          [ 0.11240619],
#          [ 0.12877604],
#          ...,
#          [ 0.02904715],
#          [ 0.1726415 ],
#          [ 0.03661693]],
#
#         [[ 0.13675639],
#          [ 0.20001362],
#          [ 0.02957885],
#          ...,
#          [-0.08156966],
#          [ 0.11134703],
#          [ 0.14858165]],
#
#         ...,
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]],
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]],
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]]],
#
#
#        [[[ 0.23224035],
#          [ 0.129723  ],
#          [ 0.16945487],
#          ...,
#          [ 0.23603655],
#          [ 0.13371864],
#          [-0.01623816]],
#
#         [[-0.11222637],
#          [ 0.13280605],
#          [ 0.15209451],
#          ...,
#          [ 0.05247113],
#          [ 0.28959522],
#          [ 0.06189571]],
#
#         [[ 0.16149767],
#          [ 0.23603307],
#          [ 0.03521139],
#          ...,
#          [-0.12997478],
#          [ 0.18961024],
#          [ 0.24712811]],
#
#         ...,
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]],
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]],
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]]],
#
#
#        [[[ 0.25823134],
#          [ 0.14433944],
#          [ 0.18847965],
#          ...,
#          [ 0.18259075],
#          [ 0.10324478],
#          [-0.01304442]],
#
#         [[-0.1244548 ],
#          [ 0.14776455],
#          [ 0.16919312],
#          ...,
#          [ 0.04023859],
#          [ 0.22412466],
#          [ 0.0475472 ]],
#
#         [[ 0.17963958],
#          [ 0.26244485],
#          [ 0.03934154],
#          ...,
#          [-0.10124542],
#          [ 0.14658786],
#          [ 0.19119209]],
#
#         ...,
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]],
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]],
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]]],
#
#
#        ...,
#
#
#        [[[ 0.24648567],
#          [ 0.13773409],
#          [ 0.17988211],
#          ...,
#          [ 0.08133583],
#          [ 0.045511  ],
#          [-0.00699375]],
#
#         [[-0.11892861],
#          [ 0.1410046 ],
#          [ 0.16146603],
#          ...,
#          [ 0.0170636 ],
#          [ 0.10008844],
#          [ 0.02036345]],
#
#         [[ 0.17144102],
#          [ 0.25050902],
#          [ 0.03747507],
#          ...,
#          [-0.04681664],
#          [ 0.06508046],
#          [ 0.08521934]],
#
#         ...,
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]],
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]],
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]]],
#
#
#        [[[-0.03570589],
#          [ 0.03796894],
#          [ 0.0901602 ],
#          ...,
#          [ 0.16996118],
#          [-0.19097875],
#          [ 0.25949636]],
#
#         [[ 0.00147783],
#          [-0.09890032],
#          [-0.06398354],
#          ...,
#          [-0.6593046 ],
#          [-0.75158453],
#          [-0.12747946]],
#
#         [[ 0.04873257],
#          [-0.02870984],
#          [ 0.08589211],
#          ...,
#          [-1.0994095 ],
#          [-0.3845047 ],
#          [-0.15468773]],
#
#         ...,
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]],
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]],
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]]],
#
#
#        [[[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]],
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]],
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]],
#
#         ...,
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]],
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]],
#
#         [[-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ],
#          ...,
#          [-0.0020131 ],
#          [-0.0020131 ],
#          [-0.0020131 ]]]], shape=(75, 1705, 30, 1), dtype=float32)

# %%
features.shape
# Out:
# (75, 1705, 30, 1)

# %% [markdown]
# ## cluster

# %%
from sklearn.cluster import AgglomerativeClustering
Agg_Clustering = AgglomerativeClustering(n_clusters = n_clusters)
features = np.reshape(features, newshape = (features.shape[0], -1))
pred = Agg_Clustering.fit_predict(features)
# Out:
# /var/folders/9l/11hrvfp943dgcqnmsc9cqgdh0000gn/T/ipykernel_21522/3639874242.py:3: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   features = np.reshape(features, newshape = (features.shape[0], -1))

# %%
pred
# Out:
# array([3, 1, 1, 3, 3, 3, 1, 1, 0, 0, 3, 3, 3, 3, 3, 3, 3, 3, 3, 1, 3, 3,
#        3, 1, 3, 3, 3, 3, 3, 3, 3, 1, 4, 1, 3, 3, 1, 0, 0, 3, 1, 0, 1, 1,
#        3, 3, 3, 3, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 1, 0, 1, 1, 0, 1, 2, 3])

# %%
indices = np.array(indices)
indices.shape
# Out:
# (75,)

# %%
clustered_data = np.vstack((indices, pred)).T

# %%
cluster_df = pd.DataFrame(clustered_data, columns = ['Index','Cluster'])
cluster_df['Cluster'] = cluster_df['Cluster'].astype(np.int32)
cluster_df
# Out:
#    Index  Cluster
# 0   ARKK        3
# 1   ARKQ        1
# 2   ARKW        1
# 3   CIBR        3
# 4   CQQQ        3
# ..   ...      ...
# 70   XLK        1
# 71  XNTK        0
# 72   XSD        1
# 73   XSW        2
# 74    XT        3
#
# [75 rows x 2 columns]

# %%
cluster_df.to_csv('etfs_tech_cluster_Index_data.csv')
